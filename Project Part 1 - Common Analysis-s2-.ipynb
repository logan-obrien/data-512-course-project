# %% [markdown]
# # Project Part 1 - Common Analysis

# %% [markdown]
# **Author: Logan O'Brien**

# %% [markdown]
# ## Step 1 Continued: Create the Fire Smoke Estimates

# %% [markdown]
# Once again we begin by importing the necessary packages

# %%
import os, json, time
from pyproj import Transformer, Geod

#importing [4]
from wildfire.Reader import Reader as WFReader

import numpy as np
import requests
from tqdm import tqdm
import pandas as pd
from datetime import datetime

# %% [markdown]
# **Note, I heavily rely upon Dr. McDonald's "wildfire_geo_proximity_example.ipynb" to learn how the wildfire data is structured as well as how to work with it [3]. In the subsequent steps, I will call out when I use code from that notebook.**

# %% [markdown]
# Now, at this point we have already filtered the wildfire data to the fires we care about in another notebook. So let's load that filtered data and continue.

# %% [markdown]
# We begin by loading the data, where I employ modified code from two cells in [3].

# %%
# I modified this file path to make it point to where I stored the file
# DATA_FILENAME = './wildfire/Wildfire_short_sample.json'
DATA_FILENAME = './data/relevant_fires.json'

#
#    This bit of code opens a new wildfire reader
#
print(f"Attempting to open '{DATA_FILENAME}' with wildfire.Reader() object")
wfreader = WFReader(DATA_FILENAME)
# Out:
# Attempting to open './data/relevant_fires.json' with wildfire.Reader() object

# %% [markdown]
# Now, let's use the Professor's Reader program in his wildfire module to load the data [4]. I employ a cell from [3] and modify some comments.

# %%
#    This code loads file, or a small amount of the complete dataset
MAX_FEATURE_LOAD = 500
feature_list = list()
feature_count = 0
# A rewind() on the reader object makes sure we're at the start of the feature list
# This way, we can execute this cell multiple times and get the same result 
wfreader.rewind()
# Now, read through each of the features, saving them as dictionaries into a list
feature = wfreader.next()
while feature:
    feature_list.append(feature)
    feature_count += 1
    # if we're loading a lot of features, print progress
    if (feature_count % 100) == 0:
        print(f"Loaded {feature_count} features")
    # loaded the max we're allowed then break
#     if feature_count >= MAX_FEATURE_LOAD:
#         break
    feature = wfreader.next()
#
#    Print the number of items (features) we think we loaded
print(f"Loaded a total of {feature_count} features")
#
#    Just a validation check - did all the items we loaded get into the list?
print(f"Variable 'feature_list' contains {len(feature_list)} features")
# Out:
# Loaded 100 features
# Loaded 200 features
# Loaded 300 features
# Loaded 400 features
# Loaded 500 features
# Loaded 600 features
# Loaded 700 features
# Loaded 800 features
# Loaded 900 features
# Loaded 1000 features
# Loaded 1100 features
# Loaded 1200 features
# Loaded 1300 features
# Loaded 1400 features
# Loaded 1500 features
# Loaded 1600 features
# Loaded 1700 features
# Loaded 1800 features
# Loaded 1900 features
# Loaded 2000 features
# Loaded 2100 features
# Loaded 2200 features
# Loaded 2300 features
# Loaded 2400 features
# Loaded 2500 features
# Loaded 2600 features
# Loaded 2700 features
# Loaded 2800 features
# Loaded 2900 features
# Loaded 3000 features
# Loaded 3100 features
# Loaded 3200 features
# Loaded 3300 features
# Loaded 3400 features
# Loaded 3500 features
# Loaded 3600 features
# Loaded 3700 features
# Loaded 3800 features
# Loaded 3900 features
# Loaded 4000 features
# Loaded 4100 features
# Loaded 4200 features
# Loaded 4300 features
# Loaded 4400 features
# Loaded 4500 features
# Loaded 4600 features
# Loaded 4700 features
# Loaded 4800 features
# Loaded 4900 features
# Loaded 5000 features
# Loaded 5100 features
# Loaded 5200 features
# Loaded 5300 features
# Loaded 5400 features
# Loaded 5500 features
# Loaded 5600 features
# Loaded 5700 features
# Loaded 5800 features
# Loaded 5900 features
# Loaded 6000 features
# Loaded 6100 features
# Loaded 6200 features
# Loaded 6300 features
# Loaded 6400 features
# Loaded 6500 features
# Loaded 6600 features
# Loaded 6700 features
# Loaded 6800 features
# Loaded 6900 features
# Loaded 7000 features
# Loaded 7100 features
# Loaded 7200 features
# Loaded 7300 features
# Loaded 7400 features
# Loaded 7500 features
# Loaded 7600 features
# Loaded 7700 features
# Loaded 7800 features
# Loaded 7900 features
# Loaded 8000 features
# Loaded 8100 features
# Loaded 8200 features
# Loaded 8300 features
# Loaded 8400 features
# Loaded 8500 features
# Loaded 8600 features
# Loaded 8700 features
# Loaded 8800 features
# Loaded 8900 features
# Loaded 9000 features
# Loaded 9100 features
# Loaded 9200 features
# Loaded 9300 features
# Loaded 9400 features
# Loaded 9500 features
# Loaded 9600 features
# Loaded 9700 features
# Loaded 9800 features
# Loaded 9900 features
# Loaded 10000 features
# Loaded 10100 features
# Loaded 10200 features
# Loaded 10300 features
# Loaded 10400 features
# Loaded 10500 features
# Loaded 10600 features
# Loaded 10700 features
# Loaded 10800 features
# Loaded 10900 features
# Loaded 11000 features
# Loaded 11100 features
# Loaded 11200 features
# Loaded 11300 features
# Loaded 11400 features
# Loaded 11500 features
# Loaded 11600 features
# Loaded 11700 features
# Loaded 11800 features
# Loaded 11900 features
# Loaded 12000 features
# Loaded 12100 features
# Loaded 12200 features
# Loaded 12300 features
# Loaded 12400 features
# Loaded 12500 features
# Loaded 12600 features
# Loaded 12700 features
# Loaded 12800 features
# Loaded 12900 features
# Loaded 13000 features
# Loaded 13100 features
# Loaded 13200 features
# Loaded 13300 features
# Loaded 13400 features
# Loaded 13500 features
# Loaded 13600 features
# Loaded 13700 features
# Loaded 13800 features
# Loaded 13900 features
# Loaded 14000 features
# Loaded 14100 features
# Loaded 14200 features
# Loaded 14300 features
# Loaded 14400 features
# Loaded 14500 features
# Loaded 14600 features
# Loaded 14700 features
# Loaded 14800 features
# Loaded 14900 features
# Loaded 15000 features
# Loaded 15100 features
# Loaded 15200 features
# Loaded 15300 features
# Loaded 15400 features
# Loaded 15500 features
# Loaded 15600 features
# Loaded 15700 features
# Loaded 15800 features
# Loaded 15900 features
# Loaded 16000 features
# Loaded 16100 features
# Loaded 16200 features
# Loaded 16300 features
# Loaded 16400 features
# Loaded 16500 features
# Loaded 16600 features
# Loaded 16700 features
# Loaded 16800 features
# Loaded 16900 features
# Loaded 17000 features
# Loaded 17100 features
# Loaded 17200 features
# Loaded 17300 features
# Loaded 17400 features
# Loaded 17500 features
# Loaded 17600 features
# Loaded 17700 features
# Loaded 17800 features
# Loaded 17900 features
# Loaded 18000 features
# Loaded 18100 features
# Loaded 18200 features
# Loaded 18300 features
# Loaded 18400 features
# Loaded 18500 features
# Loaded 18600 features
# Loaded 18700 features
# Loaded 18800 features
# Loaded 18900 features
# Loaded 19000 features
# Loaded 19100 features
# Loaded 19200 features
# Loaded 19300 features
# Loaded 19400 features
# Loaded 19500 features
# Loaded 19600 features
# Loaded 19700 features
# Loaded 19800 features
# Loaded 19900 features
# Loaded 20000 features
# Loaded 20100 features
# Loaded 20200 features
# Loaded 20300 features
# Loaded 20400 features
# Loaded 20500 features
# Loaded 20600 features
# Loaded 20700 features
# Loaded 20800 features
# Loaded 20900 features
# Loaded 21000 features
# Loaded 21100 features
# Loaded 21200 features
# Loaded 21300 features
# Loaded 21400 features
# Loaded 21500 features
# Loaded 21600 features
# Loaded 21700 features
# Loaded 21800 features
# Loaded 21900 features
# Loaded 22000 features
# Loaded 22100 features
# Loaded 22200 features
# Loaded 22300 features
# Loaded 22400 features
# Loaded 22500 features
# Loaded 22600 features
# Loaded 22700 features
# Loaded 22800 features
# Loaded 22900 features
# Loaded 23000 features
# Loaded 23100 features
# Loaded 23200 features
# Loaded 23300 features
# Loaded 23400 features
# Loaded 23500 features
# Loaded 23600 features
# Loaded 23700 features
# Loaded 23800 features
# Loaded 23900 features
# Loaded 24000 features
# Loaded 24100 features
# Loaded 24200 features
# Loaded 24300 features
# Loaded 24400 features
# Loaded 24500 features
# Loaded 24600 features
# Loaded 24700 features
# Loaded 24800 features
# Loaded 24900 features
# Loaded 25000 features
# Loaded 25100 features
# Loaded 25200 features
# Loaded 25300 features
# Loaded 25400 features
# Loaded 25500 features
# Loaded 25600 features
# Loaded 25700 features
# Loaded 25800 features
# Loaded 25900 features
# Loaded 26000 features
# Loaded 26100 features
# Loaded 26200 features
# Loaded 26300 features
# Loaded 26400 features
# Loaded 26500 features
# Loaded 26600 features
# Loaded 26700 features
# Loaded 26800 features
# Loaded 26900 features
# Loaded 27000 features
# Loaded 27100 features
# Loaded 27200 features
# Loaded 27300 features
# Loaded 27400 features
# Loaded 27500 features
# Loaded 27600 features
# Loaded 27700 features
# Loaded 27800 features
# Loaded 27900 features
# Loaded 28000 features
# Loaded 28100 features
# Loaded 28200 features
# Loaded 28300 features
# Loaded 28400 features
# Loaded 28500 features
# Loaded 28600 features
# Loaded 28700 features
# Loaded 28800 features
# Loaded 28900 features
# Loaded 29000 features
# Loaded 29100 features
# Loaded 29200 features
# Loaded 29300 features
# Loaded 29400 features
# Loaded 29500 features
# Loaded 29600 features
# Loaded 29700 features
# Loaded 29800 features
# Loaded 29900 features
# Loaded 30000 features
# Loaded 30100 features
# Loaded 30200 features
# Loaded 30300 features
# Loaded 30400 features
# Loaded 30500 features
# Loaded 30600 features
# Loaded 30700 features
# Loaded 30800 features
# Loaded 30900 features
# Loaded 31000 features
# Loaded 31100 features
# Loaded 31200 features
# Loaded 31300 features
# Loaded 31400 features
# Loaded 31500 features
# Loaded 31600 features
# Loaded 31700 features
# Loaded 31800 features
# Loaded 31900 features
# Loaded 32000 features
# Loaded 32100 features
# Loaded 32200 features
# Loaded 32300 features
# Loaded 32400 features
# Loaded 32500 features
# Loaded 32600 features
# Loaded 32700 features
# Loaded 32800 features
# Loaded 32900 features
# Loaded 33000 features
# Loaded 33100 features
# Loaded 33200 features
# Loaded 33300 features
# Loaded 33400 features
# Loaded 33500 features
# Loaded 33600 features
# Loaded 33700 features
# Loaded 33800 features
# Loaded 33900 features
# Loaded 34000 features
# Loaded 34100 features
# Loaded 34200 features
# Loaded 34300 features
# Loaded 34400 features
# Loaded 34500 features
# Loaded 34600 features
# Loaded 34700 features
# Loaded 34800 features
# Loaded 34900 features
# Loaded 35000 features
# Loaded 35100 features
# Loaded 35200 features
# Loaded 35300 features
# Loaded 35400 features
# Loaded 35500 features
# Loaded 35600 features
# Loaded 35700 features
# Loaded 35800 features
# Loaded 35900 features
# Loaded 36000 features
# Loaded 36100 features
# Loaded 36200 features
# Loaded 36300 features
# Loaded 36400 features
# Loaded 36500 features
# Loaded 36600 features
# Loaded 36700 features
# Loaded 36800 features
# Loaded 36900 features
# Loaded 37000 features
# Loaded 37100 features
# Loaded 37200 features
# Loaded 37300 features
# Loaded 37400 features
# Loaded 37500 features
# Loaded 37600 features
# Loaded 37700 features
# Loaded 37800 features
# Loaded 37900 features
# Loaded 38000 features
# Loaded 38100 features
# Loaded 38200 features
# Loaded 38300 features
# Loaded 38400 features
# Loaded 38500 features
# Loaded 38600 features
# Loaded 38700 features
# Loaded 38800 features
# Loaded 38900 features
# Loaded 39000 features
# Loaded 39100 features
# Loaded 39200 features
# Loaded 39300 features
# Loaded 39400 features
# Loaded 39500 features
# Loaded 39600 features
# Loaded 39700 features
# Loaded 39800 features
# Loaded 39900 features
# Loaded 40000 features
# Loaded 40100 features
# Loaded 40200 features
# Loaded 40300 features
# Loaded 40400 features
# Loaded 40500 features
# Loaded 40600 features
# Loaded 40700 features
# Loaded 40800 features
# Loaded 40900 features
# Loaded 41000 features
# Loaded 41100 features
# Loaded 41200 features
# Loaded 41300 features
# Loaded 41400 features
# Loaded 41500 features
# Loaded 41600 features
# Loaded 41700 features
# Loaded 41800 features
# Loaded 41900 features
# Loaded 42000 features
# Loaded 42100 features
# Loaded 42200 features
# Loaded 42300 features
# Loaded 42400 features
# Loaded 42500 features
# Loaded 42600 features
# Loaded 42700 features
# Loaded 42800 features
# Loaded 42900 features
# Loaded 43000 features
# Loaded 43100 features
# Loaded 43200 features
# Loaded 43300 features
# Loaded 43400 features
# Loaded 43500 features
# Loaded 43600 features
# Loaded 43700 features
# Loaded 43800 features
# Loaded 43900 features
# Loaded 44000 features
# Loaded 44100 features
# Loaded 44200 features
# Loaded 44300 features
# Loaded 44400 features
# Loaded 44500 features
# Loaded 44600 features
# Loaded 44700 features
# Loaded 44800 features
# Loaded 44900 features
# Loaded 45000 features
# Loaded 45100 features
# Loaded 45200 features
# Loaded 45300 features
# Loaded 45400 features
# Loaded 45500 features
# Loaded 45600 features
# Loaded 45700 features
# Loaded 45800 features
# Loaded 45900 features
# Loaded 46000 features
# Loaded 46100 features
# Loaded 46200 features
# Loaded 46300 features
# Loaded 46400 features
# Loaded 46500 features
# Loaded 46600 features
# Loaded 46700 features
# Loaded 46800 features
# Loaded 46900 features
# Loaded 47000 features
# Loaded 47100 features
# Loaded 47200 features
# Loaded 47300 features
# Loaded 47400 features
# Loaded 47500 features
# Loaded 47600 features
# Loaded 47700 features
# Loaded 47800 features
# Loaded 47900 features
# Loaded 48000 features
# Loaded 48100 features
# Loaded 48200 features
# Loaded 48300 features
# Loaded 48400 features
# Loaded 48500 features
# Loaded 48600 features
# Loaded 48700 features
# Loaded 48800 features
# Loaded 48900 features
# Loaded 49000 features
# Loaded 49100 features
# Loaded 49200 features
# Loaded 49300 features
# Loaded 49400 features
# Loaded 49500 features
# Loaded 49600 features
# Loaded 49700 features
# Loaded 49800 features
# Loaded 49900 features
# Loaded 50000 features
# Loaded 50100 features
# Loaded 50200 features
# Loaded 50300 features
# Loaded 50400 features
# Loaded 50500 features
# Loaded 50600 features
# Loaded 50700 features
# Loaded 50800 features
# Loaded 50900 features
# Loaded 51000 features
# Loaded 51100 features
# Loaded 51200 features
# Loaded 51300 features
# Loaded 51400 features
# Loaded 51500 features
# Loaded 51600 features
# Loaded 51700 features
# Loaded 51800 features
# Loaded 51900 features
# Loaded 52000 features
# Loaded 52100 features
# Loaded 52200 features
# Loaded 52300 features
# Loaded 52400 features
# Loaded 52500 features
# Loaded 52600 features
# Loaded 52700 features
# Loaded 52800 features
# Loaded 52900 features
# Loaded 53000 features
# Loaded 53100 features
# Loaded 53200 features
# Loaded 53300 features
# Loaded 53400 features
# Loaded 53500 features
# Loaded 53600 features
# Loaded 53700 features
# Loaded 53800 features
# Loaded 53900 features
# Loaded 54000 features
# Loaded 54100 features
# Loaded 54200 features
# Loaded 54300 features
# Loaded 54400 features
# Loaded 54500 features
# Loaded 54600 features
# Loaded 54700 features
# Loaded 54800 features
# Loaded 54900 features
# Loaded 55000 features
# Loaded 55100 features
# Loaded 55200 features
# Loaded 55300 features
# Loaded 55400 features
# Loaded 55500 features
# Loaded 55600 features
# Loaded 55700 features
# Loaded 55800 features
# Loaded 55900 features
# Loaded 56000 features
# Loaded 56100 features
# Loaded 56200 features
# Loaded 56300 features
# Loaded 56400 features
# Loaded 56500 features
# Loaded 56600 features
# Loaded 56700 features
# Loaded 56800 features
# Loaded 56900 features
# Loaded 57000 features
# Loaded 57100 features
# Loaded 57200 features
# Loaded 57300 features
# Loaded 57400 features
# Loaded 57500 features
# Loaded 57600 features
# Loaded 57700 features
# Loaded 57800 features
# Loaded 57900 features
# Loaded 58000 features
# Loaded 58100 features
# Loaded 58200 features
# Loaded 58300 features
# Loaded 58400 features
# Loaded 58500 features
# Loaded 58600 features
# Loaded 58700 features
# Loaded 58800 features
# Loaded 58900 features
# Loaded 59000 features
# Loaded 59100 features
# Loaded 59200 features
# Loaded 59300 features
# Loaded 59400 features
# Loaded 59500 features
# Loaded 59600 features
# Loaded 59700 features
# Loaded 59800 features
# Loaded 59900 features
# Loaded 60000 features
# Loaded 60100 features
# Loaded 60200 features
# Loaded 60300 features
# Loaded 60400 features
# Loaded 60500 features
# Loaded 60600 features
# Loaded 60700 features
# Loaded 60800 features
# Loaded 60900 features
# Loaded 61000 features
# Loaded 61100 features
# Loaded 61200 features
# Loaded 61300 features
# Loaded 61400 features
# Loaded 61500 features
# Loaded 61600 features
# Loaded 61700 features
# Loaded 61800 features
# Loaded 61900 features
# Loaded 62000 features
# Loaded 62100 features
# Loaded 62200 features
# Loaded 62300 features
# Loaded 62400 features
# Loaded 62500 features
# Loaded 62600 features
# Loaded 62700 features
# Loaded 62800 features
# Loaded 62900 features
# Loaded 63000 features
# Loaded 63100 features
# Loaded 63200 features
# Loaded 63300 features
# Loaded 63400 features
# Loaded 63500 features
# Loaded 63600 features
# Loaded 63700 features
# Loaded 63800 features
# Loaded 63900 features
# Loaded 64000 features
# Loaded 64100 features
# Loaded 64200 features
# Loaded 64300 features
# Loaded 64400 features
# Loaded 64500 features
# Loaded 64600 features
# Loaded 64700 features
# Loaded 64800 features
# Loaded 64900 features
# Loaded 65000 features
# Loaded 65100 features
# Loaded 65200 features
# Loaded 65300 features
# Loaded 65400 features
# Loaded 65500 features
# Loaded 65600 features
# Loaded 65700 features
# Loaded 65800 features
# Loaded 65900 features
# Loaded 66000 features
# Loaded 66100 features
# Loaded 66200 features
# Loaded 66300 features
# Loaded 66400 features
# Loaded 66500 features
# Loaded 66600 features
# Loaded 66700 features
# Loaded 66800 features
# Loaded 66900 features
# Loaded 67000 features
# Loaded 67100 features
# Loaded 67200 features
# Loaded 67300 features
# Loaded 67400 features
# Loaded 67500 features
# Loaded 67600 features
# Loaded 67700 features
# Loaded 67800 features
# Loaded 67900 features
# Loaded 68000 features
# Loaded 68100 features
# Loaded 68200 features
# Loaded 68300 features
# Loaded 68400 features
# Loaded 68500 features
# Loaded 68600 features
# Loaded 68700 features
# Loaded 68800 features
# Loaded 68900 features
# Loaded 69000 features
# Loaded 69100 features
# Loaded 69200 features
# Loaded 69300 features
# Loaded 69400 features
# Loaded 69500 features
# Loaded 69600 features
# Loaded 69700 features
# Loaded 69800 features
# Loaded 69900 features
# Loaded 70000 features
# Loaded 70100 features
# Loaded 70200 features
# Loaded 70300 features
# Loaded 70400 features
# Loaded 70500 features
# Loaded 70600 features
# Loaded 70700 features
# Loaded 70800 features
# Loaded 70900 features
# Loaded 71000 features
# Loaded 71100 features
# Loaded 71200 features
# Loaded 71300 features
# Loaded 71400 features
# Loaded 71500 features
# Loaded 71600 features
# Loaded 71700 features
# Loaded 71800 features
# Loaded 71900 features
# Loaded 72000 features
# Loaded 72100 features
# Loaded 72200 features
# Loaded 72300 features
# Loaded 72400 features
# Loaded 72500 features
# Loaded 72600 features
# Loaded 72700 features
# Loaded 72800 features
# Loaded 72900 features
# Loaded 73000 features
# Loaded 73100 features
# Loaded 73200 features
# Loaded 73300 features
# Loaded 73400 features
# Loaded 73500 features
# Loaded 73600 features
# Loaded 73700 features
# Loaded 73800 features
# Loaded 73900 features
# Loaded 74000 features
# Loaded 74100 features
# Loaded 74200 features
# Loaded 74300 features
# Loaded 74400 features
# Loaded 74500 features
# Loaded 74600 features
# Loaded 74700 features
# Loaded 74800 features
# Loaded 74900 features
# Loaded 75000 features
# Loaded 75100 features
# Loaded 75200 features
# Loaded 75300 features
# Loaded 75400 features
# Loaded 75500 features
# Loaded 75600 features
# Loaded 75700 features
# Loaded 75800 features
# Loaded 75900 features
# Loaded 76000 features
# Loaded 76100 features
# Loaded 76200 features
# Loaded 76300 features
# Loaded 76400 features
# Loaded a total of 76407 features
# Variable 'feature_list' contains 76407 features

# %% [markdown]
# ## Create an Estimate for the Smoke Severity

# %% [markdown]
# The next task is to design a smoke estimate and apply it to my fires.

# %% [markdown]
# **Description of my Smoke Estimate:**

# %% [markdown]
# Our next task is to create a smoke estimate.
# First, I consider what will I allow for my range of values. According to airnow.gov, the AQI index ranges from 0 to 500, where 0 is the cleanest air and 500 is the worst [10]. Now, because the assignment requires me to compare my smoke estimate to the AQI information from the EPA, I would like to try to encourage a similar range for most of my estimates.
#
# Next, I consider what factors I want to be incorporated into my smoke severity estimate. The assignment instructions provide several helpful ideas saying "It seems reasonable that a large fire, that burns a large number of acres, and that is close to a city would put more smoke into a city than a small fire that is much further away." After giving it some thought, I will base my estimate off 1). each fire's size, measured in the number of acres burned, and 2). its distance from Richland as calculated earlier above.
#
# Let's think about each of these factors, starting with acres burned. Now, it makes sense that my smoke estimate should be increase for larger fires and decrease for smaller fires, all else being equal. Additionally, a fire closer to Richland should result in poorer smoke conditions than a fire far away. Taken together, these two factors are at odds with each other, and so I decided to take their ratio for my smoke estimate - yielding: ***acres_burned / distance_from_city***.
#
# There are several more changes to make to this estimate to improve it a bit. First, we can convert the acres burned to square miles burned so that the numerator and denominator have the same units. As an aside, the resulting units are now 1/mi, and to be honest I am not sure how to think about a smoke estimator with a unit attached to it, so for the sake of this assignment, I will not concern myself with the estimate's units.
#
# While designing my estimator, I revisited the course lecture notes from 10-30-23 and looked at the professor's findings from his exporatory data analysis. According to lecture, about 94% of all fires are between 0 and 5000 acres (approx. 7.8 square miles), but the largest was 1.4M acres (approx. 2,100 square miles). In contrast, the distances I will consider will be no greater than 1,250 miles from Richland. Because the majority of these areas burned are small relative to the distances, I added a scaling factor to the numerator so it will be weighted more evenly, by multiplying by 100.
#
# I also wanted to reduce the frequency of more extreme values in my smoke estimates, and so I enforce a heuristic that the minimum distance a fire can be from the city is 1 mile, and that any fire closer than that is treated by the estimate as 1 mile. Simillarly, I enforce a minimum size of burned area (0.5 square miles). Lastly, I want to ensure my estimate has a minimum value of 1, so I take the argmax of the expression and thus my final estimate is:
# $$argmax(\frac{\text{(square_mi_burned * 100)}}{\text{distance_from_city}}, 1)$$
#
# Below is the function I defined to calculate my smoke estimate.

# %%
#distance_from_city should be provided in miles
def calc_smoke_severity_est(acres_burned, distance_from_city):
    SCALING_FACTOR = 100
    
    #convert acres to square miles. I got formula from Google [10]
    square_mi_burned = acres_burned / 640
#     print("acres_burned {}".format(acres_burned))
#     print("square_mi_burned {}".format(square_mi_burned))
    
    #to simplify the estimate, set 1 as the minimum
    #distance and 0.5 as the minimum square miles burned
#     print("distance from Richland {}".format(distance_from_city))
    if distance_from_city < 1:
        distance_from_city = 1
    
    if square_mi_burned < 0.5:
        square_mi_burned = 0.5
    
    # I learned how to do argmax() in python from [12] and [13]
    value = (square_mi_burned * SCALING_FACTOR) / distance_from_city
    options = [value, 1]
    index = np.argmax([(square_mi_burned * SCALING_FACTOR) / distance_from_city, 1])
    result = options[index]
#     print("Result: {}".format(result))
#     print('')
    return result

# %% [markdown]
# Now, let's apply the function to my list of relevant fires and store the results in a dataframe. First we convert the list of fires to a dataframe.

# %%
# Consulted for how to create the dataframe:
# https://www.geeksforgeeks.org/create-a-pandas-dataframe-from-list-of-dicts/#
feature_list
df_fires = pd.DataFrame.from_records(feature_list)
df_fires
# Out:
#        OBJECTID  USGS_Assigned_ID Assigned_Fire_Type  Fire_Year  \
# 0         14299             14299           Wildfire       1963
# 1         14300             14300           Wildfire       1963
# 2         14301             14301           Wildfire       1963
# 3         14302             14302           Wildfire       1963
# 4         14303             14303           Wildfire       1963
# ...         ...               ...                ...        ...
# 76402    135057            135057    Prescribed Fire       2020
# 76403    135058            135058    Prescribed Fire       2020
# 76404    135059            135059    Prescribed Fire       2020
# 76405    135060            135060    Prescribed Fire       2020
# 76406    135061            135061    Prescribed Fire       2020
#
#        Fire_Polygon_Tier  Fire_Attribute_Tiers     GIS_Acres  GIS_Hectares  \
# 0                      1          1 (1), 3 (3)  40992.458271  16589.059302
# 1                      1          1 (1), 3 (3)  25757.090203  10423.524591
# 2                      1  1 (5), 3 (15), 5 (1)  45527.210986  18424.208617
# 3                      1   1 (1), 3 (3), 5 (1)  10395.010334   4206.711433
# 4                      1          1 (1), 3 (3)   9983.605738   4040.221900
# ...                  ...                   ...           ...           ...
# 76402                  8                 8 (3)     16.412148      6.641761
# 76403                  8                 8 (1)      7.050837      2.853373
# 76404                  8                 8 (4)      9.342668      3.780843
# 76405                  8                 8 (1)      0.996962      0.403456
# 76406                  8                 8 (1)      0.969953      0.392526
#
#                                          Source_Datasets  \
# 0      Comb_National_NIFC_Interagency_Fire_Perimeter_...
# 1      Comb_National_NIFC_Interagency_Fire_Perimeter_...
# 2      Comb_National_NIFC_Interagency_Fire_Perimeter_...
# 3      Comb_National_NIFC_Interagency_Fire_Perimeter_...
# 4      Comb_National_NIFC_Interagency_Fire_Perimeter_...
# ...                                                  ...
# 76402  Comb_National_Rx_Only_BLM_VTRT_Prescribed_Fire...
# 76403  Comb_National_Rx_Only_BLM_VTRT_Prescribed_Fire...
# 76404  Comb_National_Rx_Only_BLM_VTRT_Prescribed_Fire...
# 76405  Comb_National_Rx_Only_BLM_VTRT_Prescribed_Fire...
# 76406  Comb_National_Rx_Only_BLM_VTRT_Prescribed_Fire...
#
#                         Listed_Fire_Types  ...  \
# 0       Wildfire (1), Likely Wildfire (3)  ...
# 1       Wildfire (2), Likely Wildfire (2)  ...
# 2      Wildfire (6), Likely Wildfire (15)  ...
# 3       Wildfire (2), Likely Wildfire (3)  ...
# 4       Wildfire (1), Likely Wildfire (3)  ...
# ...                                   ...  ...
# 76402                 Prescribed Fire (3)  ...
# 76403                 Prescribed Fire (1)  ...
# 76404                 Prescribed Fire (4)  ...
# 76405                 Prescribed Fire (1)  ...
# 76406                 Prescribed Fire (1)  ...
#
#                                          Wildfire_Notice  \
# 0      Wildfire mapping prior to 1984 was inconsisten...
# 1      Wildfire mapping prior to 1984 was inconsisten...
# 2      Wildfire mapping prior to 1984 was inconsisten...
# 3      Wildfire mapping prior to 1984 was inconsisten...
# 4      Wildfire mapping prior to 1984 was inconsisten...
# ...                                                  ...
# 76402  Wildfire mapping prior to 1984 was inconsisten...
# 76403  Wildfire mapping prior to 1984 was inconsisten...
# 76404  Wildfire mapping prior to 1984 was inconsisten...
# 76405  Wildfire mapping prior to 1984 was inconsisten...
# 76406  Wildfire mapping prior to 1984 was inconsisten...
#
#                                   Prescribed_Burn_Notice Wildfire_and_Rx_Flag  \
# 0      Prescribed fire data in this dataset represent...                 None
# 1      Prescribed fire data in this dataset represent...                 None
# 2      Prescribed fire data in this dataset represent...                 None
# 3      Prescribed fire data in this dataset represent...                 None
# 4      Prescribed fire data in this dataset represent...                 None
# ...                                                  ...                  ...
# 76402  Prescribed fire data in this dataset represent...                 None
# 76403  Prescribed fire data in this dataset represent...                 None
# 76404  Prescribed fire data in this dataset represent...                 None
# 76405  Prescribed fire data in this dataset represent...                 None
# 76406  Prescribed fire data in this dataset represent...                 None
#
#                               Overlap_Within_1_or_2_Flag Circleness_Scale  \
# 0                                                   None         0.385355
# 1                                                   None         0.364815
# 2                                                   None         0.320927
# 3                                                   None         0.428936
# 4                                                   None         0.703178
# ...                                                  ...              ...
# 76402  Caution, this Prescribed Fire in 2020 overlaps...         0.177425
# 76403  Caution, this Prescribed Fire in 2020 overlaps...         0.374368
# 76404  Caution, this Prescribed Fire in 2020 overlaps...         0.123888
# 76405                                               None         0.993809
# 76406  Caution, this Prescribed Fire in 2020 overlaps...         0.744794
#
#       Circle_Flag Exclude_From_Summary_Rasters  Shape_Length    Shape_Area  \
# 0             NaN                           No  73550.428118  1.658906e+08
# 1             NaN                           No  59920.576713  1.042352e+08
# 2             NaN                           No  84936.827810  1.842421e+08
# 3             NaN                           No  35105.903602  4.206711e+07
# 4             NaN                           No  26870.456126  4.040222e+07
# ...           ...                          ...           ...           ...
# 76402         NaN                           No   2168.900740  6.641761e+04
# 76403         NaN                           No    978.666221  2.853373e+04
# 76404         NaN                           No   1958.326660  3.780843e+04
# 76405         1.0                           No    225.866452  4.034562e+03
# 76406         NaN                           No    257.348237  3.925261e+03
#
#       distance_to_richland
# 0               189.757596
# 1               163.213533
# 2               190.823448
# 3               273.615572
# 4               205.770574
# ...                    ...
# 76402           248.914999
# 76403           167.983467
# 76404           168.822089
# 76405           655.423767
# 76406           224.477677
#
# [76407 rows x 31 columns]

# %% [markdown]
# Next we apply our smoke estimate and store it.

# %%
# I tried to vectorize this but couldn't figure it out: 
# https://tryolabs.com/blog/2023/02/08/top-5-tips-to-make-your-pandas-code-absurdly-fast

#https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas
# recommends using apply, but I used the webpage to learn how to use iterrows anyway.

# df_fires['my_smoke_estimate'] = calc_smoke_severity_est(df_fires['GIS_Acres'],
#                                                         df_fires['distance_to_richland'])
smoke_est_list = []

for index, row in df_fires.iterrows():
    smoke_est = calc_smoke_severity_est(row['GIS_Acres'], row['distance_to_richland'])
    smoke_est_list.append(smoke_est)
    
#add column to dataframe
df_fires['my_smoke_estimate'] = smoke_est_list
df_fires
# Out:
#        OBJECTID  USGS_Assigned_ID Assigned_Fire_Type  Fire_Year  \
# 0         14299             14299           Wildfire       1963
# 1         14300             14300           Wildfire       1963
# 2         14301             14301           Wildfire       1963
# 3         14302             14302           Wildfire       1963
# 4         14303             14303           Wildfire       1963
# ...         ...               ...                ...        ...
# 76402    135057            135057    Prescribed Fire       2020
# 76403    135058            135058    Prescribed Fire       2020
# 76404    135059            135059    Prescribed Fire       2020
# 76405    135060            135060    Prescribed Fire       2020
# 76406    135061            135061    Prescribed Fire       2020
#
#        Fire_Polygon_Tier  Fire_Attribute_Tiers     GIS_Acres  GIS_Hectares  \
# 0                      1          1 (1), 3 (3)  40992.458271  16589.059302
# 1                      1          1 (1), 3 (3)  25757.090203  10423.524591
# 2                      1  1 (5), 3 (15), 5 (1)  45527.210986  18424.208617
# 3                      1   1 (1), 3 (3), 5 (1)  10395.010334   4206.711433
# 4                      1          1 (1), 3 (3)   9983.605738   4040.221900
# ...                  ...                   ...           ...           ...
# 76402                  8                 8 (3)     16.412148      6.641761
# 76403                  8                 8 (1)      7.050837      2.853373
# 76404                  8                 8 (4)      9.342668      3.780843
# 76405                  8                 8 (1)      0.996962      0.403456
# 76406                  8                 8 (1)      0.969953      0.392526
#
#                                          Source_Datasets  \
# 0      Comb_National_NIFC_Interagency_Fire_Perimeter_...
# 1      Comb_National_NIFC_Interagency_Fire_Perimeter_...
# 2      Comb_National_NIFC_Interagency_Fire_Perimeter_...
# 3      Comb_National_NIFC_Interagency_Fire_Perimeter_...
# 4      Comb_National_NIFC_Interagency_Fire_Perimeter_...
# ...                                                  ...
# 76402  Comb_National_Rx_Only_BLM_VTRT_Prescribed_Fire...
# 76403  Comb_National_Rx_Only_BLM_VTRT_Prescribed_Fire...
# 76404  Comb_National_Rx_Only_BLM_VTRT_Prescribed_Fire...
# 76405  Comb_National_Rx_Only_BLM_VTRT_Prescribed_Fire...
# 76406  Comb_National_Rx_Only_BLM_VTRT_Prescribed_Fire...
#
#                         Listed_Fire_Types  ...  \
# 0       Wildfire (1), Likely Wildfire (3)  ...
# 1       Wildfire (2), Likely Wildfire (2)  ...
# 2      Wildfire (6), Likely Wildfire (15)  ...
# 3       Wildfire (2), Likely Wildfire (3)  ...
# 4       Wildfire (1), Likely Wildfire (3)  ...
# ...                                   ...  ...
# 76402                 Prescribed Fire (3)  ...
# 76403                 Prescribed Fire (1)  ...
# 76404                 Prescribed Fire (4)  ...
# 76405                 Prescribed Fire (1)  ...
# 76406                 Prescribed Fire (1)  ...
#
#                                   Prescribed_Burn_Notice Wildfire_and_Rx_Flag  \
# 0      Prescribed fire data in this dataset represent...                 None
# 1      Prescribed fire data in this dataset represent...                 None
# 2      Prescribed fire data in this dataset represent...                 None
# 3      Prescribed fire data in this dataset represent...                 None
# 4      Prescribed fire data in this dataset represent...                 None
# ...                                                  ...                  ...
# 76402  Prescribed fire data in this dataset represent...                 None
# 76403  Prescribed fire data in this dataset represent...                 None
# 76404  Prescribed fire data in this dataset represent...                 None
# 76405  Prescribed fire data in this dataset represent...                 None
# 76406  Prescribed fire data in this dataset represent...                 None
#
#                               Overlap_Within_1_or_2_Flag Circleness_Scale  \
# 0                                                   None         0.385355
# 1                                                   None         0.364815
# 2                                                   None         0.320927
# 3                                                   None         0.428936
# 4                                                   None         0.703178
# ...                                                  ...              ...
# 76402  Caution, this Prescribed Fire in 2020 overlaps...         0.177425
# 76403  Caution, this Prescribed Fire in 2020 overlaps...         0.374368
# 76404  Caution, this Prescribed Fire in 2020 overlaps...         0.123888
# 76405                                               None         0.993809
# 76406  Caution, this Prescribed Fire in 2020 overlaps...         0.744794
#
#       Circle_Flag Exclude_From_Summary_Rasters  Shape_Length    Shape_Area  \
# 0             NaN                           No  73550.428118  1.658906e+08
# 1             NaN                           No  59920.576713  1.042352e+08
# 2             NaN                           No  84936.827810  1.842421e+08
# 3             NaN                           No  35105.903602  4.206711e+07
# 4             NaN                           No  26870.456126  4.040222e+07
# ...           ...                          ...           ...           ...
# 76402         NaN                           No   2168.900740  6.641761e+04
# 76403         NaN                           No    978.666221  2.853373e+04
# 76404         NaN                           No   1958.326660  3.780843e+04
# 76405         1.0                           No    225.866452  4.034562e+03
# 76406         NaN                           No    257.348237  3.925261e+03
#
#       distance_to_richland my_smoke_estimate
# 0               189.757596         33.753967
# 1               163.213533         24.658160
# 2               190.823448         37.278578
# 3               273.615572          5.936140
# 4               205.770574          7.580960
# ...                    ...               ...
# 76402           248.914999          1.000000
# 76403           167.983467          1.000000
# 76404           168.822089          1.000000
# 76405           655.423767          1.000000
# 76406           224.477677          1.000000
#
# [76407 rows x 32 columns]

# %% [markdown]
# ## Compare My Smoke Estimate with US EPA's AQI

# %% [markdown]
# ### Acquire AQI Data

# %% [markdown]
# The first thing we need to do to compare my smoke estimate with the AQI data is to acquire the AQI data. **Note, for many of the subsequent steps, I base my work heavily upon Dr. McDonald's AQI example notebook [14].**
#
# First, I directly copied a cell from [14] to define useful constants.

# %%
#########
#
#    CONSTANTS
#

#
#    This is the root of all AQS API URLs
#
API_REQUEST_URL = 'https://aqs.epa.gov/data/api'

#
#    These are 'actions' we can ask the API to take or requests that we can make of the API
#
#    Sign-up request - generally only performed once - unless you lose your key
API_ACTION_SIGNUP = '/signup?email={email}'
#
#    List actions provide information on API parameter values that are required by some other actions/requests
API_ACTION_LIST_CLASSES = '/list/classes?email={email}&key={key}'
API_ACTION_LIST_PARAMS = '/list/parametersByClass?email={email}&key={key}&pc={pclass}'
API_ACTION_LIST_SITES = '/list/sitesByCounty?email={email}&key={key}&state={state}&county={county}'
#
#    Monitor actions are requests for monitoring stations that meet specific criteria
API_ACTION_MONITORS_COUNTY = '/monitors/byCounty?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&state={state}&county={county}'
API_ACTION_MONITORS_BOX = '/monitors/byBox?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&minlat={minlat}&maxlat={maxlat}&minlon={minlon}&maxlon={maxlon}'
#
#    Summary actions are requests for summary data. These are for daily summaries
API_ACTION_DAILY_SUMMARY_COUNTY = '/dailyData/byCounty?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&state={state}&county={county}'
API_ACTION_DAILY_SUMMARY_BOX = '/dailyData/byBox?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&minlat={minlat}&maxlat={maxlat}&minlon={minlon}&maxlon={maxlon}'
#
#    It is always nice to be respectful of a free data resource.
#    We're going to observe a 100 requests per minute limit - which is fairly nice
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED
#
#
#    This is a template that covers most of the parameters for the actions we might take, from the set of actions
#    above. In the examples below, most of the time parameters can either be supplied as individual values to a
#    function - or they can be set in a copy of the template and passed in with the template.
# 
AQS_REQUEST_TEMPLATE = {
    "email":      "",     
    "key":        "",      
    "state":      "",     # the two digit state FIPS # as a string
    "county":     "",     # the three digit county FIPS # as a string
    "begin_date": "",     # the start of a time window in YYYYMMDD format
    "end_date":   "",     # the end of a time window in YYYYMMDD format, begin_date and end_date must be in the same year
    "minlat":    0.0,
    "maxlat":    0.0,
    "minlon":    0.0,
    "maxlon":    0.0,
    "param":     "",     # a list of comma separated 5 digit codes, max 5 codes requested
    "pclass":    ""      # parameter class is only used by the List calls
}

# %% [markdown]
# Next, I again reuse a cell from [14] to define a function that requests data from the EPA.

# %%
#
#    This implements the list request. There are several versions of the list request that only require email and key.
#    This code sets the default action/requests to list the groups or parameter class descriptors. Having those descriptors 
#    allows one to request the individual (proprietary) 5 digit codes for individual air quality measures by using the
#    param request. Some code in later cells will illustrate those requests.
#
def request_list_info(email_address = None, key = None,
                      endpoint_url = API_REQUEST_URL, 
                      endpoint_action = API_ACTION_LIST_CLASSES, 
                      request_template = AQS_REQUEST_TEMPLATE,
                      headers = None):
    
    #  Make sure we have email and key - at least
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    
    # For the basic request we need an email address and a key
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_list_info()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_list_info()'")

    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
        
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %% [markdown]
# According to the professor's example in [14], there are 7 pollutants that sensors may provide data on:
# - Carbon Monoxide
# - Sulfur dioxide
# - Nitrogen dioxide
# - Ozone
# - "PM10 Total 0-10um STP"
# - "PM2.5 - Local Conditions"
# - "Acceptable PM2.5 AQI & Speciation Mass"
#
# The natural question is which ones should we focus on? According to a guide on the AQI, Ozone and particle pollution are "the major sources of unhealthy air quality around 99% of the time" ([17] pg 18). Additionally, in an article on why wildfire pollutants are unsafe, the EPA says "Particle pollution represents a main component of wildfire smoke and the principal public health threat" [18]. Based on these reasons, I will ignore the gaseous pollutants: carbon monixide, sulfur dioxide, and nitrogen dioxide for my analysis, to simplify things.
#
# Therefore, reusing and modifying a cell from [14] we define a constant with the codes corresponding to the particle pollutants.

# %%
#
#   Given the set of sensor codes, now we can create a parameter list or 'param' value as defined by the AQS API spec.
#   It turns out that we want all of these measures for AQI, but we need to have two different param constants to get
#   all seven of the code types. We can only have a max of 5 sensors/values request per param.
#
#   Gaseous AQI pollutants CO, SO2, NO2, and O2
# AQI_PARAMS_GASEOUS = "42101,42401,42602,44201"
#
#   Particulate AQI pollutants PM10, PM2.5, and Acceptable PM2.5
AQI_PARAMS_PARTICULATES = "81102,88101,88502"
#   
#

# %% [markdown]
# **TBD: REDACT!!!!!!!!!!!!**

# %% [markdown]
# Now, I followed the steps in [14] to create an account for the API I will be using to get the AQI data. For the sake of privacy, I have redacted the information

# %%
USERNAME = "obrienl@uw.edu"
APIKEY = "bolefrog68"

# %% [markdown]
# Now we determine which sensors are near Richland WA. Let's start with checking if there are any sensors in the county (Benton). According to [15] and [16], the FIPS code for Benton county is 53005 when you put together the state and county FIPS numbers. Note: I modified the two cells from [14] directly below to use Richland instead of two other city locations.

# %%
#
#   We'll use these two city locations in the examples below.
#
CITY_LOCATIONS = {
    'richland' :       {'city'   : 'Richland',
                       'county' : 'Benton',
                       'state'  : 'Washington',
                       'fips'   : '53005',
                       'latlon' : [46.28569070, -119.28446210] }
}

# %%
#
#  This list request should give us a list of all the monitoring stations in the county specified by the
#  given city selected from the CITY_LOCATIONS dictionary
#
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['state'] = CITY_LOCATIONS['richland']['fips'][:2]   # the first two digits (characters) of FIPS is the state code
request_data['county'] = CITY_LOCATIONS['richland']['fips'][2:]  # the last three digits (characters) of FIPS is the county code

response = request_list_info(request_template=request_data, endpoint_action=API_ACTION_LIST_SITES)

if response["Header"][0]['status'] == "Success":
    print(json.dumps(response['Data'],indent=4))
else:
    print(json.dumps(response,indent=4))
# Out:
# [
#     {
#         "code": "0001",
#         "value_represented": null
#     },
#     {
#         "code": "0002",
#         "value_represented": "KENNEWICK - METALINE"
#     },
#     {
#         "code": "0003",
#         "value_represented": "Kennewick_S Clodfelter Rd"
#     },
#     {
#         "code": "0004",
#         "value_represented": null
#     },
#     {
#         "code": "1001",
#         "value_represented": null
#     }
# ]

# %% [markdown]
# Looking at the data returned above, I am pleased to see that there are several monitoring stations within Benton County. The professor points out in the assingment instructions that even if there are monitoring stations within the same county as your city, it is unlikely that there will be any within the city limits. Thus, I will also use a "geodetic bounding box" to determine which monitoring stations are even closer to the city (assignment instructions), particularly the closest one. The following cell is copied from [14].

# %%
#
#   These are rough estimates for creating bounding boxes based on a city location
#   You can find these rough estimates on the USGS website:
#   https://www.usgs.gov/faqs/how-much-distance-does-a-degree-minute-and-second-cover-your-maps
#
LAT_25MILES = 25.0 * (1.0/69.0)    # This is about 25 miles of latitude in decimal degrees
LON_25MILES = 25.0 * (1.0/54.6)    # This is about 25 miles of longitude in decimal degrees
#
#   Compute a rough estimates for a bounding box around a given place
#   The bounding box is scaled in 50 mile increments. That is the bounding box will have sides that
#   are rough multiples of 50 miles, with the center of the box around the indicated place.
#   The scale parameter determines the scale (size) of the bounding box
#
def bounding_latlon(place=None,scale=1.0):
    minlat = place['latlon'][0] - float(scale) * LAT_25MILES
    maxlat = place['latlon'][0] + float(scale) * LAT_25MILES
    minlon = place['latlon'][1] - float(scale) * LON_25MILES
    maxlon = place['latlon'][1] + float(scale) * LON_25MILES
    return [minlat,maxlat,minlon,maxlon]

# %% [markdown]
# After defining the bounding function above, we next resuse a cell from [14] to define a request function.

# %%
#
#    This implements the monitors request. This requests monitoring stations. This can be done by state, county, or bounding box. 
#
#    Like the two other functions, this can be called with a mixture of a defined parameter dictionary, or with function
#    parameters. If function parameters are provided, those take precedence over any parameters from the request template.
#
def request_monitors(email_address = None, key = None, param=None,
                          begin_date = None, end_date = None, fips = None,
                          endpoint_url = API_REQUEST_URL, 
                          endpoint_action = API_ACTION_MONITORS_COUNTY, 
                          request_template = AQS_REQUEST_TEMPLATE,
                          headers = None):
    
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    if param:
        request_template['param'] = param
    if begin_date:
        request_template['begin_date'] = begin_date
    if end_date:
        request_template['end_date'] = end_date
    if fips and len(fips)==5:
        request_template['state'] = fips[:2]
        request_template['county'] = fips[2:]            

    # Make sure there are values that allow us to make a call - these are always required
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_monitors()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_monitors()'")
    if not request_template['param']: 
        raise Exception("Must supply param values to call 'request_monitors()'")
    if not request_template['begin_date']: 
        raise Exception("Must supply a begin_date to call 'request_monitors()'")
    if not request_template['end_date']: 
        raise Exception("Must supply an end_date to call 'request_monitors()'")
    # Note we're not validating FIPS fields because not all of the monitors actions require the FIPS numbers
    
    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
    
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %% [markdown]
# At this point, we can call the function using a geographic region. I modified a cell from [14] where the professor wrote code to do this. I tested various scale values and found that there is a single monitoring station within the region when the scale is set to $0.25$. It's address as seen below is: 5929 W METALINE (Kennewick Skills Center), Kennewick, WA.

# %%
#
#    Create a copy of the AQS_REQUEST_TEMPLATE
#
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_PARTICULATES     # same particulate request as the one abover
# 
#   Not going to use these - comment them out
#request_data['state'] = CITY_LOCATIONS['bend']['fips'][:2]
#request_data['county'] = CITY_LOCATIONS['bend']['fips'][2:]
#
#   Now, we need bounding box parameters

#------------------------LO--------------------------------
bbox = bounding_latlon(CITY_LOCATIONS['richland'],scale=0.25)

#-------------------------------------------------------------

#   50 mile box
# bbox = bounding_latlon(CITY_LOCATIONS['richland'],scale=1.0)
#   100 mile box
#bbox = bounding_latlon(CITY_LOCATIONS['bend'],scale=2.0)
#   150 mile box
#bbox = bounding_latlon(CITY_LOCATIONS['bend'],scale=3.0)
#   200 mile box
#bbox = bounding_latlon(CITY_LOCATIONS['bend'],scale=4.0)

# the bbox response comes back as a list - [minlat,maxlat,minlon,maxlon]

#   put our bounding box into the request_data
request_data['minlat'] = bbox[0]
request_data['maxlat'] = bbox[1]
request_data['minlon'] = bbox[2]
request_data['maxlon'] = bbox[3]

#
#   we need to change the action for the API from the default to the bounding box - same recent date for now
response = request_monitors(request_template=request_data, begin_date="20210701", end_date="20210731",
                            endpoint_action = API_ACTION_MONITORS_BOX)
#
#
#
if response["Header"][0]['status'] == "Success":
    print(json.dumps(response['Data'],indent=4))
else:
    print(json.dumps(response,indent=4))
# Out:
# [
#     {
#         "state_code": "53",
#         "county_code": "005",
#         "site_number": "0002",
#         "parameter_code": "81102",
#         "poc": 5,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2019-04-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "122",
#         "last_method_description": "INSTRUMENT MET ONE 4 MODELS - BETA ATTENUATION",
#         "last_method_begin_date": "2019-04-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "1136",
#         "monitoring_agency": "Washington State Department Of Ecology",
#         "si_id": 16457,
#         "latitude": 46.21835,
#         "longitude": -119.204153,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 162.0,
#         "probe_height": null,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "KENNEWICK - METALINE",
#         "address": "5929 W METALINE (Kennewick Skills Center)",
#         "state_name": "Washington",
#         "county_name": "Benton",
#         "city_name": "Kennewick",
#         "cbsa_code": "28420",
#         "cbsa_name": "Kennewick-Richland, WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "53",
#         "county_code": "005",
#         "site_number": "0002",
#         "parameter_code": "88502",
#         "poc": 4,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2005-10-19",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "771",
#         "last_method_description": "Correlated Radiance Research M903 With Heated Inlet - Nephelometry",
#         "last_method_begin_date": "2005-10-19",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "1136",
#         "monitoring_agency": "Washington State Department Of Ecology",
#         "si_id": 16457,
#         "latitude": 46.21835,
#         "longitude": -119.204153,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 162.0,
#         "probe_height": null,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "KENNEWICK - METALINE",
#         "address": "5929 W METALINE (Kennewick Skills Center)",
#         "state_name": "Washington",
#         "county_name": "Benton",
#         "city_name": "Kennewick",
#         "cbsa_code": "28420",
#         "cbsa_name": "Kennewick-Richland, WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": null,
#         "tribe_name": null
#     }
# ]

# %% [markdown]
# Now, let's expand the search to the sensor locations within 50 miles of Richland to see more results. We again use the code from [14] in the cell below.

# %%
#
#    Create a copy of the AQS_REQUEST_TEMPLATE
#
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_PARTICULATES     # same particulate request as the one abover
# 
#   Not going to use these - comment them out
#request_data['state'] = CITY_LOCATIONS['bend']['fips'][:2]
#request_data['county'] = CITY_LOCATIONS['bend']['fips'][2:]
#
#   Now, we need bounding box parameters

#------------------------LO--------------------------------
#   50 mile box
# bbox = bounding_latlon(CITY_LOCATIONS['richland'],scale=0.25)

#-------------------------------------------------------------

#   50 mile box
bbox = bounding_latlon(CITY_LOCATIONS['richland'],scale=1.0)
#   100 mile box
#bbox = bounding_latlon(CITY_LOCATIONS['bend'],scale=2.0)
#   150 mile box
#bbox = bounding_latlon(CITY_LOCATIONS['bend'],scale=3.0)
#   200 mile box
#bbox = bounding_latlon(CITY_LOCATIONS['bend'],scale=4.0)

# the bbox response comes back as a list - [minlat,maxlat,minlon,maxlon]

#   put our bounding box into the request_data
request_data['minlat'] = bbox[0]
request_data['maxlat'] = bbox[1]
request_data['minlon'] = bbox[2]
request_data['maxlon'] = bbox[3]

#
#   we need to change the action for the API from the default to the bounding box - same recent date for now
response = request_monitors(request_template=request_data, begin_date="20210701", end_date="20210731",
                            endpoint_action = API_ACTION_MONITORS_BOX)
#
#
#
if response["Header"][0]['status'] == "Success":
    print(json.dumps(response['Data'],indent=4))
else:
    print(json.dumps(response,indent=4))
# Out:
# [
#     {
#         "state_code": "53",
#         "county_code": "005",
#         "site_number": "0002",
#         "parameter_code": "81102",
#         "poc": 5,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2019-04-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "122",
#         "last_method_description": "INSTRUMENT MET ONE 4 MODELS - BETA ATTENUATION",
#         "last_method_begin_date": "2019-04-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "1136",
#         "monitoring_agency": "Washington State Department Of Ecology",
#         "si_id": 16457,
#         "latitude": 46.21835,
#         "longitude": -119.204153,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 162.0,
#         "probe_height": null,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "KENNEWICK - METALINE",
#         "address": "5929 W METALINE (Kennewick Skills Center)",
#         "state_name": "Washington",
#         "county_name": "Benton",
#         "city_name": "Kennewick",
#         "cbsa_code": "28420",
#         "cbsa_name": "Kennewick-Richland, WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "53",
#         "county_code": "071",
#         "site_number": "0006",
#         "parameter_code": "81102",
#         "poc": 5,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2019-10-03",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "122",
#         "last_method_description": "INSTRUMENT MET ONE 4 MODELS - BETA ATTENUATION",
#         "last_method_begin_date": "2019-10-03",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "1136",
#         "monitoring_agency": "Washington State Department Of Ecology",
#         "si_id": 91449,
#         "latitude": 46.199901,
#         "longitude": -119.008329,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 5.0,
#         "elevation": 179.0,
#         "probe_height": null,
#         "pl_probe_location": null,
#         "local_site_name": "BURBANK - MAPLE ST",
#         "address": "755 MAPLE STREET (Columbia High School)",
#         "state_name": "Washington",
#         "county_name": "Walla Walla",
#         "city_name": "Burbank",
#         "cbsa_code": "47460",
#         "cbsa_name": "Walla Walla, WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "53",
#         "county_code": "021",
#         "site_number": "0002",
#         "parameter_code": "88502",
#         "poc": 4,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2003-01-15",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "771",
#         "last_method_description": "Correlated Radiance Research M903 With Heated Inlet - Nephelometry",
#         "last_method_begin_date": "2003-01-15",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "1136",
#         "monitoring_agency": "Washington State Department Of Ecology",
#         "si_id": 91523,
#         "latitude": 46.5754,
#         "longitude": -119.0021,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 5.0,
#         "elevation": 224.0,
#         "probe_height": 6.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "MESA - PEPOIT WAY",
#         "address": "200 PEPIOT WAY (Mesa Elementary School)",
#         "state_name": "Washington",
#         "county_name": "Franklin",
#         "city_name": "Mesa",
#         "cbsa_code": "28420",
#         "cbsa_name": "Kennewick-Richland, WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "53",
#         "county_code": "005",
#         "site_number": "0002",
#         "parameter_code": "88502",
#         "poc": 4,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2005-10-19",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "771",
#         "last_method_description": "Correlated Radiance Research M903 With Heated Inlet - Nephelometry",
#         "last_method_begin_date": "2005-10-19",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "1136",
#         "monitoring_agency": "Washington State Department Of Ecology",
#         "si_id": 16457,
#         "latitude": 46.21835,
#         "longitude": -119.204153,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 162.0,
#         "probe_height": null,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "KENNEWICK - METALINE",
#         "address": "5929 W METALINE (Kennewick Skills Center)",
#         "state_name": "Washington",
#         "county_name": "Benton",
#         "city_name": "Kennewick",
#         "cbsa_code": "28420",
#         "cbsa_name": "Kennewick-Richland, WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": null,
#         "tribe_name": null
#     }
# ]

# %% [markdown]
# **TBD Cleanup text below!!!!!**

# %% [markdown]
# **how do I use this result? Should I focus on a single monitor or combine results??????**

# %% [markdown]
# What do I know:
# - The monitor stations in the same county
# - The closest monitor station and if I do the math, it's distance from Richland
# - There are 3 types of particulate a sensor can measure.
# - There are three sites with 50 miles of Richland. Unfortuneately, the earliest was not established until 2003.
#
# By running the cell above, we see the sensors appearing within 50 miles of Richland and the pollutants that they provide. I summarized the results as follows:
# - Site 0002: PM10 Total 0-10um STP, open_date 2019-04-01 --> 5929 W METALINE, Kennewick
# - Site 0006: PM10 Total 0-10um STP, open_date 2019-10-03 --> 755 MAPLE STREET, Burbank
# - Site 0002: Acceptable PM2.5 AQI & Speciation Mass, open_date 2003-01-15 --> 200 PEPIOT WAY, Mesa
# - Site 0002: Acceptable PM2.5 AQI & Speciation Mass, open_date 2005-10-19 --> 5929 W METALINE, Kenewick
#
# I do not know the definitions of several of the terms provided in the results. In particular, I assume that the site number is a unique identifier for each location, however, this is contradicted by the fact that Site 0002 is linked to a site in Kennewick and a site in Mesa. Regardless, looking at the types of pollutant info provided, we see the two kinds are "PM10 Total 0-10um STP" and "Acceptable PM2.5 AQI & Speciation Mass". Since both of these are provided by the Kennewick 0002 site, I will solely reference that site for the AQI for my analysis, as it is the closest one to Richland - however, I do note that I am sacrificing 2 years of PM2.5 data as the Kennewick location started providing this over two years later than the Mesa 0006 site.

# %% [markdown]
# Armed with the knowledge of which sensor we will use and which pollutant types it provides data on, we proceed by writing a new API request function to get the daily values of AQI. The code in the cell below resuses a cell from [14] verbatim.

# %%
#
#    This implements the daily summary request. Daily summary provides a daily summary value for each sensor being requested
#    from the start date to the end date. 
#
#    Like the two other functions, this can be called with a mixture of a defined parameter dictionary, or with function
#    parameters. If function parameters are provided, those take precedence over any parameters from the request template.
#
def request_daily_summary(email_address = None, key = None, param=None,
                          begin_date = None, end_date = None, fips = None,
                          endpoint_url = API_REQUEST_URL, 
                          endpoint_action = API_ACTION_DAILY_SUMMARY_COUNTY, 
                          request_template = AQS_REQUEST_TEMPLATE,
                          headers = None):
    
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    if param:
        request_template['param'] = param
    if begin_date:
        request_template['begin_date'] = begin_date
    if end_date:
        request_template['end_date'] = end_date
    if fips and len(fips)==5:
        request_template['state'] = fips[:2]
        request_template['county'] = fips[2:]            

    # Make sure there are values that allow us to make a call - these are always required
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_daily_summary()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_daily_summary()'")
    if not request_template['param']: 
        raise Exception("Must supply param values to call 'request_daily_summary()'")
    if not request_template['begin_date']: 
        raise Exception("Must supply a begin_date to call 'request_daily_summary()'")
    if not request_template['end_date']: 
        raise Exception("Must supply an end_date to call 'request_daily_summary()'")
    # Note we're not validating FIPS fields because not all of the daily summary actions require the FIPS numbers
        
    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
        
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %% [markdown]
# Next, we tidy up the output by defining a summary function. The code cell below is directly copied from [14].

# %%
#
#    This is a list of field names - data - that will be extracted from each record
#
EXTRACTION_FIELDS = ['sample_duration','observation_count','arithmetic_mean','aqi']

#
#    The function creates a summary record
def extract_summary_from_response(r=None, fields=EXTRACTION_FIELDS):
    ## the result will be structured around monitoring site, parameter, and then date
    result = dict()
    data = r["Data"]
    for record in data:
        # make sure the record is set up
        site = record['site_number']
        param = record['parameter_code']
        #date = record['date_local']    # this version keeps the respnse value YYYY-
        date = record['date_local'].replace('-','') # this puts it in YYYYMMDD format
        if site not in result:
            result[site] = dict()
            result[site]['local_site_name'] = record['local_site_name']
            result[site]['site_address'] = record['site_address']
            result[site]['state'] = record['state']
            result[site]['county'] = record['county']
            result[site]['city'] = record['city']
            result[site]['pollutant_type'] = dict()
        if param not in result[site]['pollutant_type']:
            result[site]['pollutant_type'][param] = dict()
            result[site]['pollutant_type'][param]['parameter_name'] = record['parameter']
            result[site]['pollutant_type'][param]['units_of_measure'] = record['units_of_measure']
            result[site]['pollutant_type'][param]['method'] = record['method']
            result[site]['pollutant_type'][param]['data'] = dict()
        if date not in result[site]['pollutant_type'][param]['data']:
            result[site]['pollutant_type'][param]['data'][date] = list()
        
        # now extract the specified fields
        extract = dict()
        for k in fields:
            if str(k) in record:
                extract[str(k)] = record[k]
            else:
                # this makes sure we always have the requested fields, even if
                # we have a missing value for a given day/month
                extract[str(k)] = None
        
        # add this extraction to the list for the day
        result[site]['pollutant_type'][param]['data'][date].append(extract)
    
    return result

# %% [markdown]
# Next we start the proecess for requesting the daily summary data. The cell below is reused and modified from [14]. Some of the main changes I made to the cell are that:
# - I implemented the ability to loop through multiple years at once
# - I removed the request for gaseous AQI
# - I added the function call to extract_summary_from_response()
# - Commented out passing state and county arguments to try to operate by bounding box instead to get a specific site
# - Added code to pass the latlongs for the request template
# - Changed the endpoint_action to use a geographic box instead of a county.
# - TBD: pass the 4 latlong parameters to request_data
# - TBD: update particulate codes?

# %% [markdown]
# **TBD Should I update which particulates I am grabbing?**

# %%
#   Particulate AQI pollutants PM10, PM2.5, and Acceptable PM2.5
AQI_PARAMS_PARTICULATES = "81102,88101,88502"

# %%
from datetime import date 

request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_PARTICULATES
# request_data['state'] = CITY_LOCATIONS['richland']['fips'][:2]
# request_data['county'] = CITY_LOCATIONS['richland']['fips'][2:]

bbox = bounding_latlon(CITY_LOCATIONS['richland'],scale=0.25)

#   put our bounding box into the request_data
request_data['minlat'] = bbox[0]
request_data['maxlat'] = bbox[1]
request_data['minlon'] = bbox[2]
request_data['maxlon'] = bbox[3]


# request daily summary data for all years
# START_DATE = '20220101' #should be 1963
# PRESENT_DATE = '20231108'

START_DATE = '19630101' #should be 1963
PRESENT_DATE = '20231108'

# get every year between both dates
# I learned to do this from: https://stackoverflow.com/questions/23590042/get-all-years-between-two-dates-in-python
start_date = datetime.strptime(START_DATE, '%Y%m%d')
end_date = datetime.strptime(PRESENT_DATE, '%Y%m%d')


# Retrieve the AQI data for each year
particulate_aqi_ls = []
success_years = []

for year in range(start_date.year, end_date.year + 1):
    
    # determine current start and end dates
    # I referenced: https://www.geeksforgeeks.org/add-years-to-datetime-object-in-python/
    # and: https://stackoverflow.com/questions/15741618/add-one-year-in-current-date-python
    current_start_date = date(year, 1, 1)
    
    if year == end_date.year: # if you've reached final year you won't grab entire year
        current_end_date = end_date
    
    else: # otherwise your current end date is the last day of December of current year
        current_end_date = date(year, 12, 31)
    
    # get the dates in string format
    # referenced: https://www.programiz.com/python-programming/datetime/strftime
    current_start_date_str = current_start_date.strftime('%Y%m%d')
    current_end_date_str = current_end_date.strftime('%Y%m%d')
    
    # call the api -------------------------------------------------------------------------------------------------------------
    particulate_aqi = request_daily_summary(request_template=request_data, 
                                            begin_date=current_start_date_str, end_date=current_end_date_str, 
                                            endpoint_action = API_ACTION_DAILY_SUMMARY_BOX)
    # check that it worked
    print("Response for the particulate pollutants in {}...".format(year))
    #
    if particulate_aqi["Header"][0]['status'] == "Success":
    #     print(json.dumps(particulate_aqi['Data'],indent=4))
        print('Success')
        success_years.append(str(year))
        
        # tidy up output
        extract_particulate_dict = extract_summary_from_response(particulate_aqi)

        #store data
        particulate_aqi_ls.append(extract_particulate_dict)
        
    elif particulate_aqi["Header"][0]['status'].startswith("No data "):
        print("Looks like the response generated no data. You might take a closer look at your request and the response data.")
    else:
        print(json.dumps(particulate_aqi,indent=4))
    #     print('No idea what is going on')
# Out:
# Response for the particulate pollutants in 1963...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1964...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1965...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1966...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1967...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1968...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1969...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1970...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1971...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1972...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1973...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1974...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1975...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1976...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1977...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1978...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1979...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1980...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1981...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1982...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1983...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1984...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants in 1985...
# Success
# Response for the particulate pollutants in 1986...
# Success
# Response for the particulate pollutants in 1987...
# Success
# Response for the particulate pollutants in 1988...
# Success
# Response for the particulate pollutants in 1989...
# Success
# Response for the particulate pollutants in 1990...
# Success
# Response for the particulate pollutants in 1991...
# Success
# Response for the particulate pollutants in 1992...
# Success
# Response for the particulate pollutants in 1993...
# Success
# Response for the particulate pollutants in 1994...
# Success
# Response for the particulate pollutants in 1995...
# Success
# Response for the particulate pollutants in 1996...
# Success
# Response for the particulate pollutants in 1997...
# Success
# Response for the particulate pollutants in 1998...
# Success
# Response for the particulate pollutants in 1999...
# Success
# Response for the particulate pollutants in 2000...
# Success
# Response for the particulate pollutants in 2001...
# Success
# Response for the particulate pollutants in 2002...
# Success
# Response for the particulate pollutants in 2003...
# Success
# Response for the particulate pollutants in 2004...
# Success
# Response for the particulate pollutants in 2005...
# Success
# Response for the particulate pollutants in 2006...
# Success
# Response for the particulate pollutants in 2007...
# Success
# Response for the particulate pollutants in 2008...
# Success
# Response for the particulate pollutants in 2009...
# Success
# Response for the particulate pollutants in 2010...
# Success
# Response for the particulate pollutants in 2011...
# Success
# Response for the particulate pollutants in 2012...
# Success
# Response for the particulate pollutants in 2013...
# Success
# Response for the particulate pollutants in 2014...
# Success
# Response for the particulate pollutants in 2015...
# Success
# Response for the particulate pollutants in 2016...
# Success
# Response for the particulate pollutants in 2017...
# Success
# Response for the particulate pollutants in 2018...
# Success
# Response for the particulate pollutants in 2019...
# Success
# Response for the particulate pollutants in 2020...
# Success
# Response for the particulate pollutants in 2021...
# Success
# Response for the particulate pollutants in 2022...
# Success
# Response for the particulate pollutants in 2023...
# Success

# %% [markdown]
# Call the extract summary function to tidy up the results. The cell below is reused and modified from [14].

# %%
# extract_particulate = extract_summary_from_response(particulate_aqi)
# print("Summary of particulate extraction ...")
# print(json.dumps(extract_particulate,indent=4))

# %% [markdown]
# Let's recap where we are at at this point. We are seeking to retrieve a value for AQI from the EPA API that we can compare to our smoke estimates. We have decided based on our exploration to get data from the Site 0002 in Kennewick Washington, another town in Benton county. Additionally, we have demonstrated that we can get the daily summary data for this site for a specified date range.
#
# Now, since we are ultimately going to chart the smoke estimate and AQI at the annual level, we need to figure out a way to move from a daily granularity AQI for two provided particle types, to a single AQI value for each year.

# %% [markdown]
# So, first we store the output of the extract summary as a data type that we can work with.

# %%
# extract_particulate_dict = extract_summary_from_response(particulate_aqi)

# %% [markdown]
# Now, let's retrive the information we need and make this easier to work with by storing the aqi in a couple dictionaries.

# %% [markdown]
# First, let's take a look at how many sites there are for each year

# %%
year_list = success_years
year_index = 0

# iterate through all years of data
for extract_particulate_dict in particulate_aqi_ls: # for each year
    year = year_list[year_index]
    print("------------ Retrieving data for {} ------------".format(year))
        
    # iterate through all sites
    site_keys = extract_particulate_dict.keys()
    print("There are {} sites".format(len(site_keys)))
    for site_key in site_keys:
        print(site_key)
        
    year_index = year_index + 1
# Out:
# ------------ Retrieving data for 1985 ------------
# There are 1 sites
# 0001
# ------------ Retrieving data for 1986 ------------
# There are 1 sites
# 0001
# ------------ Retrieving data for 1987 ------------
# There are 1 sites
# 0001
# ------------ Retrieving data for 1988 ------------
# There are 1 sites
# 0001
# ------------ Retrieving data for 1989 ------------
# There are 1 sites
# 0001
# ------------ Retrieving data for 1990 ------------
# There are 1 sites
# 0001
# ------------ Retrieving data for 1991 ------------
# There are 1 sites
# 0001
# ------------ Retrieving data for 1992 ------------
# There are 1 sites
# 0001
# ------------ Retrieving data for 1993 ------------
# There are 1 sites
# 0001
# ------------ Retrieving data for 1994 ------------
# There are 2 sites
# 0001
# 0002
# ------------ Retrieving data for 1995 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 1996 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 1997 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 1998 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 1999 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2000 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2001 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2002 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2003 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2004 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2005 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2006 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2007 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2008 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2009 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2010 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2011 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2012 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2013 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2014 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2015 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2016 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2017 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2018 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2019 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2020 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2021 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2022 ------------
# There are 1 sites
# 0002
# ------------ Retrieving data for 2023 ------------
# There are 1 sites
# 0002

# %% [markdown]
# By inspecting the output above, we see that for every year except 1994, there is a single site. Additionally, from 1985 to 1994 site 0001 is used and from 1994 to the present day site 0002 is used. Now, to make the coding task easier, I am going to ignore site 0001 for 1994.

# %% [markdown]
# **TBD Decision, right now, the next cell allows AQI to be None if necessary. should I change to a constant like '-1'?**

# %%
# Reference:https://www.geeksforgeeks.org/range-to-a-list-in-python/
year_list = success_years
year_index = 0

# define my dictionaries outside the loop so that the hold values for all years
pm10_aqi_dict = {}
pm25_aqi_dict = {}

pm10_is_available = False
pm25_is_available = False

# iterate through all years of data
for extract_particulate_dict in tqdm(particulate_aqi_ls): # for each year
    year = year_list[year_index]
    print("------------ Retrieving data for {} ------------".format(year))
    
    # select the site data:
    year_num = int(year)
    
    # use the hueristic described above for knowing which site to pick
    if year_num < 1994:
        site_data = extract_particulate_dict['0001']
    
    else:
        site_data = extract_particulate_dict['0002']
    
    # get the data for each pollutant type
    try: #try to get pm10 data
        pm10_data_dict = site_data['pollutant_type']['81102']['data']
    except:
        print("No pm10 data")
        pm10_data_dict = None
    else:
        # if it worked set the value to True
        pm10_is_available = True
        
    try: #try to get the pm2.5 data
        acceptable_pm2_5_data_dict = site_data['pollutant_type']['88502']['data']
    except:
        print("no pm2.5 data")
        acceptable_pm2_5_data_dict = None
    else:
        # if it worked set the value to True
        pm25_is_available = True

    # check if don't have either pollutant data
    if (not pm10_is_available) and (not pm25_is_available):
        print('No pollutant data !!!!!!!!!!!!!!!!!!!!!!!!!!')
        continue
    
    else:
        pass
    
    # iterate over the dictionaries
    # I viewed https://www.geeksforgeeks.org/iterate-over-a-dictionary-in-python/
    # to learn how to iterate over a dictionary

    if (pm10_is_available):
        # first we get lists of the keys
        pm10_data_keys = pm10_data_dict.keys()
   
        # iterate through the dictionary of dates for pm10 and grab the aqi for each
        print("Retrieving pm10 AQI data")
        pm10_missing_count = 0
        pm10_null_count = 0
        for key in pm10_data_keys:

            try:
                aqi = pm10_data_dict[key][1]['aqi']

            except:
                aqi = None
                pm10_missing_count = pm10_missing_count + 1
                print("AQI for pm10 data with date {} is missing".format(key))

            #flag potential issues
            else:
                if aqi is None:
                    print("AQI for pm10 data with date {} is null".format(key))
                    pm10_null_count = pm10_null_count + 1

            pm10_aqi_dict[key] = aqi

        print("There were {} instances of missing data.".format(pm10_missing_count)) #where no 24 hr data
        print("There were {} null values in the data.".format(pm10_null_count))
        print("Total null values retrived: {}".format(pm10_missing_count + pm10_null_count))

    if (pm25_is_available):
        # first we get lists of the keys
        acceptable_pm2_5_data_keys = acceptable_pm2_5_data_dict.keys()

        # iterate through the dictionary of dates for pm2.5 acceptability and grab the aqi for each
        print('')
        print("Retrieving pm2.5 Acceptable AQI data")
        pm25_missing_count = 0
        pm25_nulls_count = 0
        for key in acceptable_pm2_5_data_keys:

            try:
                aqi = acceptable_pm2_5_data_dict[key][1]['aqi']

            except:
                aqi = None
                pm25_missing_count = pm25_missing_count + 1
                print("AQI for pm2.5 acceptable data with date {} is null".format(key))

            #flag potential issues
            else:
                if aqi is None:
                    print("AQI for pm2.5 acceptable data with date {} is null".format(key))
                    pm25_nulls_count = pm25_nulls_count + 1

            pm25_aqi_dict[key] = aqi

        print("There were {} instances of missing data.".format(pm25_missing_count)) #where no 24 hr data
        print("There were {} null values in the data.".format(pm25_nulls_count))
        print("Total null values retrived: {}".format(pm25_missing_count + pm25_nulls_count))

    #update year index
    year_index = year_index + 1
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 39/39 [00:00<00:00, 3010.43it/s]
# ------------ Retrieving data for 1985 ------------
# no pm2.5 data
# Retrieving pm10 AQI data
# AQI for pm10 data with date 19851009 is missing
# AQI for pm10 data with date 19851010 is missing
# AQI for pm10 data with date 19851012 is missing
# AQI for pm10 data with date 19851014 is missing
# AQI for pm10 data with date 19851016 is missing
# AQI for pm10 data with date 19851018 is missing
# AQI for pm10 data with date 19851020 is missing
# AQI for pm10 data with date 19851022 is missing
# AQI for pm10 data with date 19851024 is missing
# AQI for pm10 data with date 19851026 is missing
# AQI for pm10 data with date 19851028 is missing
# AQI for pm10 data with date 19851030 is missing
# AQI for pm10 data with date 19851101 is missing
# AQI for pm10 data with date 19851103 is missing
# AQI for pm10 data with date 19851106 is missing
# AQI for pm10 data with date 19851109 is missing
# AQI for pm10 data with date 19851111 is missing
# AQI for pm10 data with date 19851113 is missing
# AQI for pm10 data with date 19851115 is missing
# AQI for pm10 data with date 19851117 is missing
# AQI for pm10 data with date 19851119 is missing
# AQI for pm10 data with date 19851121 is missing
# AQI for pm10 data with date 19851123 is missing
# AQI for pm10 data with date 19851129 is missing
# AQI for pm10 data with date 19851201 is missing
# AQI for pm10 data with date 19851205 is missing
# AQI for pm10 data with date 19851207 is missing
# AQI for pm10 data with date 19851209 is missing
# AQI for pm10 data with date 19851211 is missing
# AQI for pm10 data with date 19851213 is missing
# AQI for pm10 data with date 19851215 is missing
# AQI for pm10 data with date 19851220 is missing
# AQI for pm10 data with date 19851222 is missing
# AQI for pm10 data with date 19851224 is missing
# AQI for pm10 data with date 19851226 is missing
# AQI for pm10 data with date 19851228 is missing
# AQI for pm10 data with date 19851230 is missing
# There were 37 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 37
# ------------ Retrieving data for 1986 ------------
# no pm2.5 data
# Retrieving pm10 AQI data
# AQI for pm10 data with date 19860101 is missing
# AQI for pm10 data with date 19860103 is missing
# AQI for pm10 data with date 19860105 is missing
# AQI for pm10 data with date 19860109 is missing
# AQI for pm10 data with date 19860111 is missing
# AQI for pm10 data with date 19860113 is missing
# AQI for pm10 data with date 19860115 is missing
# AQI for pm10 data with date 19860117 is missing
# AQI for pm10 data with date 19860119 is missing
# AQI for pm10 data with date 19860121 is missing
# AQI for pm10 data with date 19860123 is missing
# AQI for pm10 data with date 19860125 is missing
# AQI for pm10 data with date 19860127 is missing
# AQI for pm10 data with date 19860129 is missing
# AQI for pm10 data with date 19860131 is missing
# AQI for pm10 data with date 19860202 is missing
# AQI for pm10 data with date 19860204 is missing
# AQI for pm10 data with date 19860206 is missing
# AQI for pm10 data with date 19860208 is missing
# AQI for pm10 data with date 19860210 is missing
# AQI for pm10 data with date 19860212 is missing
# AQI for pm10 data with date 19860214 is missing
# AQI for pm10 data with date 19860216 is missing
# AQI for pm10 data with date 19860218 is missing
# AQI for pm10 data with date 19860220 is missing
# AQI for pm10 data with date 19860222 is missing
# AQI for pm10 data with date 19860224 is missing
# AQI for pm10 data with date 19860226 is missing
# AQI for pm10 data with date 19860228 is missing
# AQI for pm10 data with date 19860302 is missing
# AQI for pm10 data with date 19860304 is missing
# AQI for pm10 data with date 19860306 is missing
# AQI for pm10 data with date 19860308 is missing
# AQI for pm10 data with date 19860311 is missing
# AQI for pm10 data with date 19860312 is missing
# AQI for pm10 data with date 19860314 is missing
# AQI for pm10 data with date 19860316 is missing
# AQI for pm10 data with date 19860318 is missing
# AQI for pm10 data with date 19860320 is missing
# AQI for pm10 data with date 19860322 is missing
# AQI for pm10 data with date 19860324 is missing
# AQI for pm10 data with date 19860326 is missing
# AQI for pm10 data with date 19860404 is missing
# AQI for pm10 data with date 19860405 is missing
# AQI for pm10 data with date 19860407 is missing
# AQI for pm10 data with date 19860409 is missing
# AQI for pm10 data with date 19860411 is missing
# AQI for pm10 data with date 19860413 is missing
# AQI for pm10 data with date 19860415 is missing
# AQI for pm10 data with date 19860417 is missing
# AQI for pm10 data with date 19860419 is missing
# AQI for pm10 data with date 19860421 is missing
# AQI for pm10 data with date 19860423 is missing
# AQI for pm10 data with date 19860425 is missing
# AQI for pm10 data with date 19860427 is missing
# AQI for pm10 data with date 19860429 is missing
# AQI for pm10 data with date 19860501 is missing
# AQI for pm10 data with date 19860503 is missing
# AQI for pm10 data with date 19860505 is missing
# AQI for pm10 data with date 19860507 is missing
# AQI for pm10 data with date 19860509 is missing
# AQI for pm10 data with date 19860511 is missing
# AQI for pm10 data with date 19860513 is missing
# AQI for pm10 data with date 19860515 is missing
# AQI for pm10 data with date 19860517 is missing
# AQI for pm10 data with date 19860519 is missing
# AQI for pm10 data with date 19860521 is missing
# AQI for pm10 data with date 19860523 is missing
# AQI for pm10 data with date 19860525 is missing
# AQI for pm10 data with date 19860528 is missing
# AQI for pm10 data with date 19860529 is missing
# AQI for pm10 data with date 19860531 is missing
# AQI for pm10 data with date 19860602 is missing
# AQI for pm10 data with date 19860604 is missing
# AQI for pm10 data with date 19860607 is missing
# AQI for pm10 data with date 19860610 is missing
# AQI for pm10 data with date 19860612 is missing
# AQI for pm10 data with date 19860614 is missing
# AQI for pm10 data with date 19860617 is missing
# AQI for pm10 data with date 19860618 is missing
# AQI for pm10 data with date 19860620 is missing
# AQI for pm10 data with date 19860622 is missing
# AQI for pm10 data with date 19860624 is missing
# AQI for pm10 data with date 19860626 is missing
# AQI for pm10 data with date 19860628 is missing
# AQI for pm10 data with date 19860630 is missing
# AQI for pm10 data with date 19860702 is missing
# AQI for pm10 data with date 19860704 is missing
# AQI for pm10 data with date 19860706 is missing
# AQI for pm10 data with date 19860708 is missing
# AQI for pm10 data with date 19860710 is missing
# AQI for pm10 data with date 19860712 is missing
# AQI for pm10 data with date 19860714 is missing
# AQI for pm10 data with date 19860716 is missing
# AQI for pm10 data with date 19860718 is missing
# AQI for pm10 data with date 19860720 is missing
# AQI for pm10 data with date 19860722 is missing
# AQI for pm10 data with date 19860724 is missing
# AQI for pm10 data with date 19860726 is missing
# AQI for pm10 data with date 19860728 is missing
# AQI for pm10 data with date 19860730 is missing
# AQI for pm10 data with date 19860801 is missing
# AQI for pm10 data with date 19860803 is missing
# AQI for pm10 data with date 19860805 is missing
# AQI for pm10 data with date 19860807 is missing
# AQI for pm10 data with date 19860809 is missing
# AQI for pm10 data with date 19860811 is missing
# AQI for pm10 data with date 19860813 is missing
# AQI for pm10 data with date 19860815 is missing
# AQI for pm10 data with date 19860817 is missing
# AQI for pm10 data with date 19860819 is missing
# AQI for pm10 data with date 19860821 is missing
# AQI for pm10 data with date 19860825 is missing
# AQI for pm10 data with date 19860827 is missing
# AQI for pm10 data with date 19860828 is missing
# AQI for pm10 data with date 19860829 is missing
# AQI for pm10 data with date 19860831 is missing
# AQI for pm10 data with date 19860903 is missing
# AQI for pm10 data with date 19860909 is missing
# AQI for pm10 data with date 19860911 is missing
# AQI for pm10 data with date 19860913 is missing
# AQI for pm10 data with date 19860915 is missing
# AQI for pm10 data with date 19860917 is missing
# AQI for pm10 data with date 19860919 is missing
# AQI for pm10 data with date 19860921 is missing
# AQI for pm10 data with date 19860923 is missing
# AQI for pm10 data with date 19860925 is missing
# AQI for pm10 data with date 19860927 is missing
# AQI for pm10 data with date 19861001 is missing
# AQI for pm10 data with date 19861003 is missing
# AQI for pm10 data with date 19861005 is missing
# AQI for pm10 data with date 19861007 is missing
# AQI for pm10 data with date 19861009 is missing
# AQI for pm10 data with date 19861011 is missing
# AQI for pm10 data with date 19861013 is missing
# AQI for pm10 data with date 19861015 is missing
# AQI for pm10 data with date 19861017 is missing
# AQI for pm10 data with date 19861019 is missing
# AQI for pm10 data with date 19861021 is missing
# AQI for pm10 data with date 19861023 is missing
# AQI for pm10 data with date 19861025 is missing
# AQI for pm10 data with date 19861027 is missing
# AQI for pm10 data with date 19861029 is missing
# AQI for pm10 data with date 19861102 is missing
# AQI for pm10 data with date 19861104 is missing
# AQI for pm10 data with date 19861106 is missing
# AQI for pm10 data with date 19861108 is missing
# AQI for pm10 data with date 19861113 is missing
# AQI for pm10 data with date 19861114 is missing
# AQI for pm10 data with date 19861116 is missing
# AQI for pm10 data with date 19861118 is missing
# AQI for pm10 data with date 19861120 is missing
# AQI for pm10 data with date 19861122 is missing
# AQI for pm10 data with date 19861124 is missing
# AQI for pm10 data with date 19861126 is missing
# AQI for pm10 data with date 19861128 is missing
# AQI for pm10 data with date 19861202 is missing
# AQI for pm10 data with date 19861203 is missing
# AQI for pm10 data with date 19861204 is missing
# AQI for pm10 data with date 19861206 is missing
# AQI for pm10 data with date 19861208 is missing
# AQI for pm10 data with date 19861210 is missing
# AQI for pm10 data with date 19861212 is missing
# AQI for pm10 data with date 19861214 is missing
# AQI for pm10 data with date 19861218 is missing
# AQI for pm10 data with date 19861220 is missing
# AQI for pm10 data with date 19861222 is missing
# AQI for pm10 data with date 19861224 is missing
# AQI for pm10 data with date 19861226 is missing
# AQI for pm10 data with date 19861228 is missing
# AQI for pm10 data with date 19861230 is missing
# There were 171 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 171
# ------------ Retrieving data for 1987 ------------
# no pm2.5 data
# Retrieving pm10 AQI data
# AQI for pm10 data with date 19870101 is missing
# AQI for pm10 data with date 19870103 is missing
# AQI for pm10 data with date 19870105 is missing
# AQI for pm10 data with date 19870107 is missing
# AQI for pm10 data with date 19870109 is missing
# AQI for pm10 data with date 19870111 is missing
# AQI for pm10 data with date 19870113 is missing
# AQI for pm10 data with date 19870115 is missing
# AQI for pm10 data with date 19870117 is missing
# AQI for pm10 data with date 19870119 is missing
# AQI for pm10 data with date 19870121 is missing
# AQI for pm10 data with date 19870123 is missing
# AQI for pm10 data with date 19870125 is missing
# AQI for pm10 data with date 19870127 is missing
# AQI for pm10 data with date 19870129 is missing
# AQI for pm10 data with date 19870131 is missing
# AQI for pm10 data with date 19870202 is missing
# AQI for pm10 data with date 19870204 is missing
# AQI for pm10 data with date 19870206 is missing
# AQI for pm10 data with date 19870208 is missing
# AQI for pm10 data with date 19870210 is missing
# AQI for pm10 data with date 19870212 is missing
# AQI for pm10 data with date 19870214 is missing
# AQI for pm10 data with date 19870216 is missing
# AQI for pm10 data with date 19870218 is missing
# AQI for pm10 data with date 19870220 is missing
# AQI for pm10 data with date 19870222 is missing
# AQI for pm10 data with date 19870224 is missing
# AQI for pm10 data with date 19870226 is missing
# AQI for pm10 data with date 19870228 is missing
# AQI for pm10 data with date 19870302 is missing
# AQI for pm10 data with date 19870304 is missing
# AQI for pm10 data with date 19870306 is missing
# AQI for pm10 data with date 19870308 is missing
# AQI for pm10 data with date 19870310 is missing
# AQI for pm10 data with date 19870312 is missing
# AQI for pm10 data with date 19870314 is missing
# AQI for pm10 data with date 19870316 is missing
# AQI for pm10 data with date 19870318 is missing
# AQI for pm10 data with date 19870320 is missing
# AQI for pm10 data with date 19870322 is missing
# AQI for pm10 data with date 19870324 is missing
# AQI for pm10 data with date 19870326 is missing
# AQI for pm10 data with date 19870328 is missing
# AQI for pm10 data with date 19870330 is missing
# AQI for pm10 data with date 19870401 is missing
# AQI for pm10 data with date 19870403 is missing
# AQI for pm10 data with date 19870405 is missing
# AQI for pm10 data with date 19870407 is missing
# AQI for pm10 data with date 19870409 is missing
# AQI for pm10 data with date 19870411 is missing
# AQI for pm10 data with date 19870413 is missing
# AQI for pm10 data with date 19870415 is missing
# AQI for pm10 data with date 19870417 is missing
# AQI for pm10 data with date 19870419 is missing
# AQI for pm10 data with date 19870421 is missing
# AQI for pm10 data with date 19870423 is missing
# AQI for pm10 data with date 19870425 is missing
# AQI for pm10 data with date 19870427 is missing
# AQI for pm10 data with date 19870429 is missing
# AQI for pm10 data with date 19870501 is missing
# AQI for pm10 data with date 19870503 is missing
# AQI for pm10 data with date 19870505 is missing
# AQI for pm10 data with date 19870507 is missing
# AQI for pm10 data with date 19870509 is missing
# AQI for pm10 data with date 19870511 is missing
# AQI for pm10 data with date 19870513 is missing
# AQI for pm10 data with date 19870515 is missing
# AQI for pm10 data with date 19870517 is missing
# AQI for pm10 data with date 19870519 is missing
# AQI for pm10 data with date 19870521 is missing
# AQI for pm10 data with date 19870523 is missing
# AQI for pm10 data with date 19870525 is missing
# AQI for pm10 data with date 19870527 is missing
# AQI for pm10 data with date 19870529 is missing
# AQI for pm10 data with date 19870531 is missing
# AQI for pm10 data with date 19870602 is missing
# AQI for pm10 data with date 19870604 is missing
# AQI for pm10 data with date 19870606 is missing
# AQI for pm10 data with date 19870608 is missing
# AQI for pm10 data with date 19870610 is missing
# AQI for pm10 data with date 19870612 is missing
# AQI for pm10 data with date 19870620 is missing
# AQI for pm10 data with date 19870624 is missing
# AQI for pm10 data with date 19870628 is missing
# AQI for pm10 data with date 19870702 is missing
# AQI for pm10 data with date 19870704 is missing
# AQI for pm10 data with date 19870710 is missing
# AQI for pm10 data with date 19870714 is missing
# AQI for pm10 data with date 19870716 is missing
# AQI for pm10 data with date 19870718 is missing
# AQI for pm10 data with date 19870722 is missing
# AQI for pm10 data with date 19870726 is missing
# AQI for pm10 data with date 19870728 is missing
# AQI for pm10 data with date 19870730 is missing
# AQI for pm10 data with date 19870801 is missing
# AQI for pm10 data with date 19870803 is missing
# AQI for pm10 data with date 19870805 is missing
# AQI for pm10 data with date 19870807 is missing
# AQI for pm10 data with date 19870809 is missing
# AQI for pm10 data with date 19870812 is missing
# AQI for pm10 data with date 19870813 is missing
# AQI for pm10 data with date 19870815 is missing
# AQI for pm10 data with date 19870817 is missing
# AQI for pm10 data with date 19870819 is missing
# AQI for pm10 data with date 19870821 is missing
# AQI for pm10 data with date 19870825 is missing
# AQI for pm10 data with date 19870827 is missing
# AQI for pm10 data with date 19870829 is missing
# AQI for pm10 data with date 19870831 is missing
# AQI for pm10 data with date 19870904 is missing
# AQI for pm10 data with date 19870906 is missing
# AQI for pm10 data with date 19870910 is missing
# AQI for pm10 data with date 19870912 is missing
# AQI for pm10 data with date 19870916 is missing
# AQI for pm10 data with date 19870917 is missing
# AQI for pm10 data with date 19870919 is missing
# AQI for pm10 data with date 19870920 is missing
# AQI for pm10 data with date 19870922 is missing
# AQI for pm10 data with date 19870924 is missing
# AQI for pm10 data with date 19870926 is missing
# AQI for pm10 data with date 19870928 is missing
# AQI for pm10 data with date 19870930 is missing
# AQI for pm10 data with date 19871004 is missing
# AQI for pm10 data with date 19871008 is missing
# AQI for pm10 data with date 19871012 is missing
# AQI for pm10 data with date 19871016 is missing
# AQI for pm10 data with date 19871020 is missing
# AQI for pm10 data with date 19871026 is missing
# AQI for pm10 data with date 19871028 is missing
# AQI for pm10 data with date 19871103 is missing
# AQI for pm10 data with date 19871107 is missing
# AQI for pm10 data with date 19871111 is missing
# AQI for pm10 data with date 19871115 is missing
# AQI for pm10 data with date 19871119 is missing
# AQI for pm10 data with date 19871121 is missing
# AQI for pm10 data with date 19871123 is missing
# AQI for pm10 data with date 19871126 is missing
# AQI for pm10 data with date 19871127 is missing
# AQI for pm10 data with date 19871129 is missing
# AQI for pm10 data with date 19871201 is missing
# AQI for pm10 data with date 19871203 is missing
# AQI for pm10 data with date 19871205 is missing
# AQI for pm10 data with date 19871207 is missing
# AQI for pm10 data with date 19871209 is missing
# AQI for pm10 data with date 19871211 is missing
# AQI for pm10 data with date 19871213 is missing
# AQI for pm10 data with date 19871215 is missing
# AQI for pm10 data with date 19871217 is missing
# AQI for pm10 data with date 19871219 is missing
# AQI for pm10 data with date 19871221 is missing
# AQI for pm10 data with date 19871223 is missing
# AQI for pm10 data with date 19871225 is missing
# AQI for pm10 data with date 19871227 is missing
# AQI for pm10 data with date 19871229 is missing
# AQI for pm10 data with date 19871231 is missing
# There were 156 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 156
# ------------ Retrieving data for 1988 ------------
# no pm2.5 data
# Retrieving pm10 AQI data
# AQI for pm10 data with date 19880104 is missing
# AQI for pm10 data with date 19880114 is missing
# AQI for pm10 data with date 19880118 is missing
# AQI for pm10 data with date 19880120 is missing
# AQI for pm10 data with date 19880124 is missing
# AQI for pm10 data with date 19880201 is missing
# AQI for pm10 data with date 19880205 is missing
# AQI for pm10 data with date 19880209 is missing
# AQI for pm10 data with date 19880218 is missing
# AQI for pm10 data with date 19880220 is missing
# AQI for pm10 data with date 19880224 is missing
# AQI for pm10 data with date 19880225 is missing
# AQI for pm10 data with date 19880227 is missing
# AQI for pm10 data with date 19880229 is missing
# AQI for pm10 data with date 19880302 is missing
# AQI for pm10 data with date 19880304 is missing
# AQI for pm10 data with date 19880306 is missing
# AQI for pm10 data with date 19880308 is missing
# AQI for pm10 data with date 19880310 is missing
# AQI for pm10 data with date 19880312 is missing
# AQI for pm10 data with date 19880314 is missing
# AQI for pm10 data with date 19880316 is missing
# AQI for pm10 data with date 19880318 is missing
# AQI for pm10 data with date 19880320 is missing
# AQI for pm10 data with date 19880322 is missing
# AQI for pm10 data with date 19880324 is missing
# AQI for pm10 data with date 19880326 is missing
# AQI for pm10 data with date 19880328 is missing
# AQI for pm10 data with date 19880330 is missing
# AQI for pm10 data with date 19880401 is missing
# AQI for pm10 data with date 19880407 is missing
# AQI for pm10 data with date 19880411 is missing
# AQI for pm10 data with date 19880417 is missing
# AQI for pm10 data with date 19880421 is missing
# AQI for pm10 data with date 19880429 is missing
# AQI for pm10 data with date 19880505 is missing
# AQI for pm10 data with date 19880507 is missing
# AQI for pm10 data with date 19880509 is missing
# AQI for pm10 data with date 19880511 is missing
# AQI for pm10 data with date 19880513 is missing
# AQI for pm10 data with date 19880515 is missing
# AQI for pm10 data with date 19880517 is missing
# AQI for pm10 data with date 19880519 is missing
# AQI for pm10 data with date 19880521 is missing
# AQI for pm10 data with date 19880523 is missing
# AQI for pm10 data with date 19880525 is missing
# AQI for pm10 data with date 19880529 is missing
# AQI for pm10 data with date 19880531 is missing
# AQI for pm10 data with date 19880602 is missing
# AQI for pm10 data with date 19880604 is missing
# AQI for pm10 data with date 19880606 is missing
# AQI for pm10 data with date 19880608 is missing
# AQI for pm10 data with date 19880610 is missing
# AQI for pm10 data with date 19880613 is missing
# AQI for pm10 data with date 19880614 is missing
# AQI for pm10 data with date 19880616 is missing
# AQI for pm10 data with date 19880618 is missing
# AQI for pm10 data with date 19880620 is missing
# AQI for pm10 data with date 19880622 is missing
# AQI for pm10 data with date 19880624 is missing
# AQI for pm10 data with date 19880626 is missing
# AQI for pm10 data with date 19880628 is missing
# AQI for pm10 data with date 19880630 is missing
# AQI for pm10 data with date 19880702 is missing
# AQI for pm10 data with date 19880704 is missing
# AQI for pm10 data with date 19880706 is missing
# AQI for pm10 data with date 19880708 is missing
# AQI for pm10 data with date 19880710 is missing
# AQI for pm10 data with date 19880712 is missing
# AQI for pm10 data with date 19880716 is missing
# AQI for pm10 data with date 19880717 is missing
# AQI for pm10 data with date 19880718 is missing
# AQI for pm10 data with date 19880720 is missing
# AQI for pm10 data with date 19880722 is missing
# AQI for pm10 data with date 19880724 is missing
# AQI for pm10 data with date 19880726 is missing
# AQI for pm10 data with date 19880728 is missing
# AQI for pm10 data with date 19880730 is missing
# AQI for pm10 data with date 19880801 is missing
# AQI for pm10 data with date 19880803 is missing
# AQI for pm10 data with date 19880805 is missing
# AQI for pm10 data with date 19880807 is missing
# AQI for pm10 data with date 19880809 is missing
# AQI for pm10 data with date 19880811 is missing
# AQI for pm10 data with date 19880813 is missing
# AQI for pm10 data with date 19880815 is missing
# AQI for pm10 data with date 19880817 is missing
# AQI for pm10 data with date 19880819 is missing
# AQI for pm10 data with date 19880821 is missing
# AQI for pm10 data with date 19880823 is missing
# AQI for pm10 data with date 19880825 is missing
# AQI for pm10 data with date 19880827 is missing
# AQI for pm10 data with date 19880829 is missing
# AQI for pm10 data with date 19880831 is missing
# AQI for pm10 data with date 19880902 is missing
# AQI for pm10 data with date 19880904 is missing
# AQI for pm10 data with date 19880906 is missing
# AQI for pm10 data with date 19880908 is missing
# AQI for pm10 data with date 19880910 is missing
# AQI for pm10 data with date 19880912 is missing
# AQI for pm10 data with date 19880914 is missing
# AQI for pm10 data with date 19880916 is missing
# AQI for pm10 data with date 19880918 is missing
# AQI for pm10 data with date 19880920 is missing
# AQI for pm10 data with date 19880922 is missing
# AQI for pm10 data with date 19880924 is missing
# AQI for pm10 data with date 19880926 is missing
# AQI for pm10 data with date 19880928 is missing
# AQI for pm10 data with date 19880930 is missing
# AQI for pm10 data with date 19881002 is missing
# AQI for pm10 data with date 19881004 is missing
# AQI for pm10 data with date 19881006 is missing
# AQI for pm10 data with date 19881008 is missing
# AQI for pm10 data with date 19881010 is missing
# AQI for pm10 data with date 19881012 is missing
# AQI for pm10 data with date 19881014 is missing
# AQI for pm10 data with date 19881016 is missing
# AQI for pm10 data with date 19881018 is missing
# AQI for pm10 data with date 19881020 is missing
# AQI for pm10 data with date 19881022 is missing
# AQI for pm10 data with date 19881024 is missing
# AQI for pm10 data with date 19881026 is missing
# AQI for pm10 data with date 19881028 is missing
# AQI for pm10 data with date 19881030 is missing
# AQI for pm10 data with date 19881101 is missing
# AQI for pm10 data with date 19881103 is missing
# AQI for pm10 data with date 19881105 is missing
# AQI for pm10 data with date 19881107 is missing
# AQI for pm10 data with date 19881109 is missing
# AQI for pm10 data with date 19881111 is missing
# AQI for pm10 data with date 19881113 is missing
# AQI for pm10 data with date 19881115 is missing
# AQI for pm10 data with date 19881117 is missing
# AQI for pm10 data with date 19881119 is missing
# AQI for pm10 data with date 19881121 is missing
# AQI for pm10 data with date 19881123 is missing
# AQI for pm10 data with date 19881127 is missing
# AQI for pm10 data with date 19881129 is missing
# AQI for pm10 data with date 19881201 is missing
# AQI for pm10 data with date 19881203 is missing
# AQI for pm10 data with date 19881205 is missing
# AQI for pm10 data with date 19881207 is missing
# AQI for pm10 data with date 19881209 is missing
# AQI for pm10 data with date 19881211 is missing
# AQI for pm10 data with date 19881213 is missing
# AQI for pm10 data with date 19881215 is missing
# AQI for pm10 data with date 19881217 is missing
# AQI for pm10 data with date 19881219 is missing
# AQI for pm10 data with date 19881221 is missing
# AQI for pm10 data with date 19881223 is missing
# AQI for pm10 data with date 19881225 is missing
# AQI for pm10 data with date 19881228 is missing
# AQI for pm10 data with date 19881229 is missing
# AQI for pm10 data with date 19881231 is missing
# There were 154 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 154
# ------------ Retrieving data for 1989 ------------
# no pm2.5 data
# Retrieving pm10 AQI data
# AQI for pm10 data with date 19890102 is missing
# AQI for pm10 data with date 19890104 is missing
# AQI for pm10 data with date 19890106 is missing
# AQI for pm10 data with date 19890108 is missing
# AQI for pm10 data with date 19890110 is missing
# AQI for pm10 data with date 19890112 is missing
# AQI for pm10 data with date 19890116 is missing
# AQI for pm10 data with date 19890118 is missing
# AQI for pm10 data with date 19890122 is missing
# AQI for pm10 data with date 19890124 is missing
# AQI for pm10 data with date 19890126 is missing
# AQI for pm10 data with date 19890128 is missing
# AQI for pm10 data with date 19890130 is missing
# AQI for pm10 data with date 19890201 is missing
# AQI for pm10 data with date 19890205 is missing
# AQI for pm10 data with date 19890209 is missing
# AQI for pm10 data with date 19890211 is missing
# AQI for pm10 data with date 19890215 is missing
# AQI for pm10 data with date 19890217 is missing
# AQI for pm10 data with date 19890219 is missing
# AQI for pm10 data with date 19890225 is missing
# AQI for pm10 data with date 19890226 is missing
# AQI for pm10 data with date 19890301 is missing
# AQI for pm10 data with date 19890303 is missing
# AQI for pm10 data with date 19890305 is missing
# AQI for pm10 data with date 19890307 is missing
# AQI for pm10 data with date 19890311 is missing
# AQI for pm10 data with date 19890313 is missing
# AQI for pm10 data with date 19890315 is missing
# AQI for pm10 data with date 19890317 is missing
# AQI for pm10 data with date 19890319 is missing
# AQI for pm10 data with date 19890321 is missing
# AQI for pm10 data with date 19890323 is missing
# AQI for pm10 data with date 19890325 is missing
# AQI for pm10 data with date 19890327 is missing
# AQI for pm10 data with date 19890329 is missing
# AQI for pm10 data with date 19890331 is missing
# AQI for pm10 data with date 19890402 is missing
# AQI for pm10 data with date 19890404 is missing
# AQI for pm10 data with date 19890410 is missing
# AQI for pm10 data with date 19890412 is missing
# AQI for pm10 data with date 19890414 is missing
# AQI for pm10 data with date 19890416 is missing
# AQI for pm10 data with date 19890418 is missing
# AQI for pm10 data with date 19890420 is missing
# AQI for pm10 data with date 19890422 is missing
# AQI for pm10 data with date 19890424 is missing
# AQI for pm10 data with date 19890426 is missing
# AQI for pm10 data with date 19890428 is missing
# AQI for pm10 data with date 19890430 is missing
# AQI for pm10 data with date 19890502 is missing
# AQI for pm10 data with date 19890504 is missing
# AQI for pm10 data with date 19890508 is missing
# AQI for pm10 data with date 19890510 is missing
# AQI for pm10 data with date 19890512 is missing
# AQI for pm10 data with date 19890518 is missing
# AQI for pm10 data with date 19890520 is missing
# AQI for pm10 data with date 19890522 is missing
# AQI for pm10 data with date 19890524 is missing
# AQI for pm10 data with date 19890525 is missing
# AQI for pm10 data with date 19890526 is missing
# AQI for pm10 data with date 19890601 is missing
# AQI for pm10 data with date 19890603 is missing
# AQI for pm10 data with date 19890604 is missing
# AQI for pm10 data with date 19890606 is missing
# AQI for pm10 data with date 19890607 is missing
# AQI for pm10 data with date 19890611 is missing
# AQI for pm10 data with date 19890613 is missing
# AQI for pm10 data with date 19890614 is missing
# AQI for pm10 data with date 19890615 is missing
# AQI for pm10 data with date 19890617 is missing
# AQI for pm10 data with date 19890619 is missing
# AQI for pm10 data with date 19890621 is missing
# AQI for pm10 data with date 19890623 is missing
# AQI for pm10 data with date 19890625 is missing
# AQI for pm10 data with date 19890627 is missing
# AQI for pm10 data with date 19890629 is missing
# AQI for pm10 data with date 19890701 is missing
# AQI for pm10 data with date 19890703 is missing
# AQI for pm10 data with date 19890705 is missing
# AQI for pm10 data with date 19890707 is missing
# AQI for pm10 data with date 19890709 is missing
# AQI for pm10 data with date 19890711 is missing
# AQI for pm10 data with date 19890713 is missing
# AQI for pm10 data with date 19890715 is missing
# AQI for pm10 data with date 19890717 is missing
# AQI for pm10 data with date 19890719 is missing
# AQI for pm10 data with date 19890721 is missing
# AQI for pm10 data with date 19890723 is missing
# AQI for pm10 data with date 19890725 is missing
# AQI for pm10 data with date 19890727 is missing
# AQI for pm10 data with date 19890729 is missing
# AQI for pm10 data with date 19890731 is missing
# AQI for pm10 data with date 19890802 is missing
# AQI for pm10 data with date 19890804 is missing
# AQI for pm10 data with date 19890806 is missing
# AQI for pm10 data with date 19890808 is missing
# AQI for pm10 data with date 19890810 is missing
# AQI for pm10 data with date 19890812 is missing
# AQI for pm10 data with date 19890814 is missing
# AQI for pm10 data with date 19890816 is missing
# AQI for pm10 data with date 19890818 is missing
# AQI for pm10 data with date 19890820 is missing
# AQI for pm10 data with date 19890822 is missing
# AQI for pm10 data with date 19890824 is missing
# AQI for pm10 data with date 19890826 is missing
# AQI for pm10 data with date 19890828 is missing
# AQI for pm10 data with date 19890830 is missing
# AQI for pm10 data with date 19890901 is missing
# AQI for pm10 data with date 19890903 is missing
# AQI for pm10 data with date 19890905 is missing
# AQI for pm10 data with date 19890907 is missing
# AQI for pm10 data with date 19890909 is missing
# AQI for pm10 data with date 19890911 is missing
# AQI for pm10 data with date 19890913 is missing
# AQI for pm10 data with date 19890915 is missing
# AQI for pm10 data with date 19890917 is missing
# AQI for pm10 data with date 19890919 is missing
# AQI for pm10 data with date 19890921 is missing
# AQI for pm10 data with date 19890923 is missing
# AQI for pm10 data with date 19890925 is missing
# AQI for pm10 data with date 19890927 is missing
# AQI for pm10 data with date 19890929 is missing
# AQI for pm10 data with date 19891001 is missing
# AQI for pm10 data with date 19891003 is missing
# AQI for pm10 data with date 19891004 is missing
# AQI for pm10 data with date 19891005 is missing
# AQI for pm10 data with date 19891009 is missing
# AQI for pm10 data with date 19891011 is missing
# AQI for pm10 data with date 19891013 is missing
# AQI for pm10 data with date 19891015 is missing
# AQI for pm10 data with date 19891017 is missing
# AQI for pm10 data with date 19891019 is missing
# AQI for pm10 data with date 19891023 is missing
# AQI for pm10 data with date 19891025 is missing
# AQI for pm10 data with date 19891027 is missing
# AQI for pm10 data with date 19891029 is missing
# AQI for pm10 data with date 19891031 is missing
# AQI for pm10 data with date 19891104 is missing
# AQI for pm10 data with date 19891106 is missing
# AQI for pm10 data with date 19891108 is missing
# AQI for pm10 data with date 19891110 is missing
# AQI for pm10 data with date 19891112 is missing
# AQI for pm10 data with date 19891114 is missing
# AQI for pm10 data with date 19891116 is missing
# AQI for pm10 data with date 19891118 is missing
# AQI for pm10 data with date 19891120 is missing
# AQI for pm10 data with date 19891122 is missing
# AQI for pm10 data with date 19891124 is missing
# AQI for pm10 data with date 19891126 is missing
# AQI for pm10 data with date 19891128 is missing
# AQI for pm10 data with date 19891202 is missing
# AQI for pm10 data with date 19891204 is missing
# AQI for pm10 data with date 19891206 is missing
# AQI for pm10 data with date 19891208 is missing
# AQI for pm10 data with date 19891210 is missing
# AQI for pm10 data with date 19891212 is missing
# AQI for pm10 data with date 19891214 is missing
# AQI for pm10 data with date 19891216 is missing
# AQI for pm10 data with date 19891218 is missing
# AQI for pm10 data with date 19891220 is missing
# AQI for pm10 data with date 19891222 is missing
# AQI for pm10 data with date 19891224 is missing
# AQI for pm10 data with date 19891226 is missing
# AQI for pm10 data with date 19891228 is missing
# AQI for pm10 data with date 19891230 is missing
# There were 166 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 166
# ------------ Retrieving data for 1990 ------------
# no pm2.5 data
# Retrieving pm10 AQI data
# AQI for pm10 data with date 19900101 is missing
# AQI for pm10 data with date 19900103 is missing
# AQI for pm10 data with date 19900105 is missing
# AQI for pm10 data with date 19900107 is missing
# AQI for pm10 data with date 19900109 is missing
# AQI for pm10 data with date 19900111 is missing
# AQI for pm10 data with date 19900113 is missing
# AQI for pm10 data with date 19900115 is missing
# AQI for pm10 data with date 19900117 is missing
# AQI for pm10 data with date 19900119 is missing
# AQI for pm10 data with date 19900121 is missing
# AQI for pm10 data with date 19900123 is missing
# AQI for pm10 data with date 19900125 is missing
# AQI for pm10 data with date 19900127 is missing
# AQI for pm10 data with date 19900129 is missing
# AQI for pm10 data with date 19900131 is missing
# AQI for pm10 data with date 19900202 is missing
# AQI for pm10 data with date 19900204 is missing
# AQI for pm10 data with date 19900206 is missing
# AQI for pm10 data with date 19900208 is missing
# AQI for pm10 data with date 19900210 is missing
# AQI for pm10 data with date 19900212 is missing
# AQI for pm10 data with date 19900214 is missing
# AQI for pm10 data with date 19900216 is missing
# AQI for pm10 data with date 19900218 is missing
# AQI for pm10 data with date 19900222 is missing
# AQI for pm10 data with date 19900226 is missing
# AQI for pm10 data with date 19900304 is missing
# AQI for pm10 data with date 19900312 is missing
# AQI for pm10 data with date 19900313 is missing
# AQI for pm10 data with date 19900314 is missing
# AQI for pm10 data with date 19900315 is missing
# AQI for pm10 data with date 19900316 is missing
# AQI for pm10 data with date 19900318 is missing
# AQI for pm10 data with date 19900320 is missing
# AQI for pm10 data with date 19900322 is missing
# AQI for pm10 data with date 19900324 is missing
# AQI for pm10 data with date 19900326 is missing
# AQI for pm10 data with date 19900328 is missing
# AQI for pm10 data with date 19900330 is missing
# AQI for pm10 data with date 19900401 is missing
# AQI for pm10 data with date 19900403 is missing
# AQI for pm10 data with date 19900405 is missing
# AQI for pm10 data with date 19900407 is missing
# AQI for pm10 data with date 19900409 is missing
# AQI for pm10 data with date 19900411 is missing
# AQI for pm10 data with date 19900415 is missing
# AQI for pm10 data with date 19900417 is missing
# AQI for pm10 data with date 19900419 is missing
# AQI for pm10 data with date 19900421 is missing
# AQI for pm10 data with date 19900423 is missing
# AQI for pm10 data with date 19900427 is missing
# AQI for pm10 data with date 19900501 is missing
# AQI for pm10 data with date 19900503 is missing
# AQI for pm10 data with date 19900602 is missing
# AQI for pm10 data with date 19900604 is missing
# AQI for pm10 data with date 19900606 is missing
# AQI for pm10 data with date 19900608 is missing
# AQI for pm10 data with date 19900614 is missing
# AQI for pm10 data with date 19900616 is missing
# AQI for pm10 data with date 19900618 is missing
# AQI for pm10 data with date 19900620 is missing
# AQI for pm10 data with date 19900622 is missing
# AQI for pm10 data with date 19900624 is missing
# AQI for pm10 data with date 19900626 is missing
# AQI for pm10 data with date 19900628 is missing
# AQI for pm10 data with date 19900702 is missing
# AQI for pm10 data with date 19900704 is missing
# AQI for pm10 data with date 19900706 is missing
# AQI for pm10 data with date 19900710 is missing
# AQI for pm10 data with date 19900712 is missing
# AQI for pm10 data with date 19900714 is missing
# AQI for pm10 data with date 19900716 is missing
# AQI for pm10 data with date 19900718 is missing
# AQI for pm10 data with date 19900720 is missing
# AQI for pm10 data with date 19900722 is missing
# AQI for pm10 data with date 19900724 is missing
# AQI for pm10 data with date 19900801 is missing
# AQI for pm10 data with date 19900803 is missing
# AQI for pm10 data with date 19900805 is missing
# AQI for pm10 data with date 19900807 is missing
# AQI for pm10 data with date 19900809 is missing
# AQI for pm10 data with date 19900811 is missing
# AQI for pm10 data with date 19900813 is missing
# AQI for pm10 data with date 19900815 is missing
# AQI for pm10 data with date 19900817 is missing
# AQI for pm10 data with date 19900819 is missing
# AQI for pm10 data with date 19900821 is missing
# AQI for pm10 data with date 19900823 is missing
# AQI for pm10 data with date 19900825 is missing
# AQI for pm10 data with date 19900827 is missing
# AQI for pm10 data with date 19900829 is missing
# AQI for pm10 data with date 19900831 is missing
# AQI for pm10 data with date 19900902 is missing
# AQI for pm10 data with date 19900904 is missing
# AQI for pm10 data with date 19900906 is missing
# AQI for pm10 data with date 19900908 is missing
# AQI for pm10 data with date 19900912 is missing
# AQI for pm10 data with date 19900914 is missing
# AQI for pm10 data with date 19900916 is missing
# AQI for pm10 data with date 19900918 is missing
# AQI for pm10 data with date 19900920 is missing
# AQI for pm10 data with date 19900922 is missing
# AQI for pm10 data with date 19900924 is missing
# AQI for pm10 data with date 19900926 is missing
# AQI for pm10 data with date 19900928 is missing
# AQI for pm10 data with date 19901002 is missing
# AQI for pm10 data with date 19901004 is missing
# AQI for pm10 data with date 19901008 is missing
# AQI for pm10 data with date 19901010 is missing
# AQI for pm10 data with date 19901012 is missing
# AQI for pm10 data with date 19901018 is missing
# AQI for pm10 data with date 19901021 is missing
# AQI for pm10 data with date 19901022 is missing
# AQI for pm10 data with date 19901023 is missing
# AQI for pm10 data with date 19901024 is missing
# AQI for pm10 data with date 19901025 is missing
# AQI for pm10 data with date 19901028 is missing
# AQI for pm10 data with date 19901029 is missing
# AQI for pm10 data with date 19901030 is missing
# AQI for pm10 data with date 19901031 is missing
# AQI for pm10 data with date 19901101 is missing
# AQI for pm10 data with date 19901104 is missing
# AQI for pm10 data with date 19901105 is missing
# AQI for pm10 data with date 19901106 is missing
# AQI for pm10 data with date 19901107 is missing
# AQI for pm10 data with date 19901108 is missing
# AQI for pm10 data with date 19901112 is missing
# AQI for pm10 data with date 19901113 is missing
# AQI for pm10 data with date 19901114 is missing
# AQI for pm10 data with date 19901115 is missing
# AQI for pm10 data with date 19901118 is missing
# AQI for pm10 data with date 19901119 is missing
# AQI for pm10 data with date 19901120 is missing
# AQI for pm10 data with date 19901122 is missing
# AQI for pm10 data with date 19901123 is missing
# AQI for pm10 data with date 19901126 is missing
# AQI for pm10 data with date 19901127 is missing
# AQI for pm10 data with date 19901128 is missing
# AQI for pm10 data with date 19901130 is missing
# AQI for pm10 data with date 19901203 is missing
# AQI for pm10 data with date 19901205 is missing
# AQI for pm10 data with date 19901208 is missing
# AQI for pm10 data with date 19901210 is missing
# AQI for pm10 data with date 19901211 is missing
# AQI for pm10 data with date 19901213 is missing
# AQI for pm10 data with date 19901215 is missing
# AQI for pm10 data with date 19901218 is missing
# AQI for pm10 data with date 19901219 is missing
# AQI for pm10 data with date 19901220 is missing
# AQI for pm10 data with date 19901221 is missing
# AQI for pm10 data with date 19901222 is missing
# AQI for pm10 data with date 19901226 is missing
# AQI for pm10 data with date 19901227 is missing
# AQI for pm10 data with date 19901228 is missing
# There were 155 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 155
# ------------ Retrieving data for 1991 ------------
# no pm2.5 data
# Retrieving pm10 AQI data
# AQI for pm10 data with date 19910101 is missing
# AQI for pm10 data with date 19910102 is missing
# AQI for pm10 data with date 19910103 is missing
# AQI for pm10 data with date 19910104 is missing
# AQI for pm10 data with date 19910107 is missing
# AQI for pm10 data with date 19910108 is missing
# AQI for pm10 data with date 19910109 is missing
# AQI for pm10 data with date 19910110 is missing
# AQI for pm10 data with date 19910112 is missing
# AQI for pm10 data with date 19910114 is missing
# AQI for pm10 data with date 19910115 is missing
# AQI for pm10 data with date 19910116 is missing
# AQI for pm10 data with date 19910117 is missing
# AQI for pm10 data with date 19910118 is missing
# AQI for pm10 data with date 19910119 is missing
# AQI for pm10 data with date 19910122 is missing
# AQI for pm10 data with date 19910123 is missing
# AQI for pm10 data with date 19910124 is missing
# AQI for pm10 data with date 19910125 is missing
# AQI for pm10 data with date 19910126 is missing
# AQI for pm10 data with date 19910129 is missing
# AQI for pm10 data with date 19910130 is missing
# AQI for pm10 data with date 19910131 is missing
# AQI for pm10 data with date 19910202 is missing
# AQI for pm10 data with date 19910203 is missing
# AQI for pm10 data with date 19910205 is missing
# AQI for pm10 data with date 19910206 is missing
# AQI for pm10 data with date 19910207 is missing
# AQI for pm10 data with date 19910209 is missing
# AQI for pm10 data with date 19910212 is missing
# AQI for pm10 data with date 19910213 is missing
# AQI for pm10 data with date 19910214 is missing
# AQI for pm10 data with date 19910215 is missing
# AQI for pm10 data with date 19910216 is missing
# AQI for pm10 data with date 19910221 is missing
# AQI for pm10 data with date 19910222 is missing
# AQI for pm10 data with date 19910225 is missing
# AQI for pm10 data with date 19910226 is missing
# AQI for pm10 data with date 19910227 is missing
# AQI for pm10 data with date 19910228 is missing
# AQI for pm10 data with date 19910301 is missing
# AQI for pm10 data with date 19910305 is missing
# AQI for pm10 data with date 19910306 is missing
# AQI for pm10 data with date 19910307 is missing
# AQI for pm10 data with date 19910308 is missing
# AQI for pm10 data with date 19910309 is missing
# AQI for pm10 data with date 19910312 is missing
# AQI for pm10 data with date 19910313 is missing
# AQI for pm10 data with date 19910314 is missing
# AQI for pm10 data with date 19910315 is missing
# AQI for pm10 data with date 19910316 is missing
# AQI for pm10 data with date 19910319 is missing
# AQI for pm10 data with date 19910320 is missing
# AQI for pm10 data with date 19910321 is missing
# AQI for pm10 data with date 19910322 is missing
# AQI for pm10 data with date 19910323 is missing
# AQI for pm10 data with date 19910325 is missing
# AQI for pm10 data with date 19910326 is missing
# AQI for pm10 data with date 19910327 is missing
# AQI for pm10 data with date 19910328 is missing
# AQI for pm10 data with date 19910329 is missing
# AQI for pm10 data with date 19910330 is missing
# AQI for pm10 data with date 19910331 is missing
# AQI for pm10 data with date 19910402 is missing
# AQI for pm10 data with date 19910403 is missing
# AQI for pm10 data with date 19910404 is missing
# AQI for pm10 data with date 19910405 is missing
# AQI for pm10 data with date 19910406 is missing
# AQI for pm10 data with date 19910409 is missing
# AQI for pm10 data with date 19910411 is missing
# AQI for pm10 data with date 19910412 is missing
# AQI for pm10 data with date 19910413 is missing
# AQI for pm10 data with date 19910416 is missing
# AQI for pm10 data with date 19910417 is missing
# AQI for pm10 data with date 19910419 is missing
# AQI for pm10 data with date 19910420 is missing
# AQI for pm10 data with date 19910421 is missing
# AQI for pm10 data with date 19910423 is missing
# AQI for pm10 data with date 19910424 is missing
# AQI for pm10 data with date 19910425 is missing
# AQI for pm10 data with date 19910426 is missing
# AQI for pm10 data with date 19910427 is missing
# AQI for pm10 data with date 19910430 is missing
# AQI for pm10 data with date 19910501 is missing
# AQI for pm10 data with date 19910503 is missing
# AQI for pm10 data with date 19910504 is missing
# AQI for pm10 data with date 19910505 is missing
# AQI for pm10 data with date 19910506 is missing
# AQI for pm10 data with date 19910508 is missing
# AQI for pm10 data with date 19910509 is missing
# AQI for pm10 data with date 19910510 is missing
# AQI for pm10 data with date 19910511 is missing
# AQI for pm10 data with date 19910512 is missing
# AQI for pm10 data with date 19910514 is missing
# AQI for pm10 data with date 19910515 is missing
# AQI for pm10 data with date 19910518 is missing
# AQI for pm10 data with date 19910519 is missing
# AQI for pm10 data with date 19910521 is missing
# AQI for pm10 data with date 19910522 is missing
# AQI for pm10 data with date 19910523 is missing
# AQI for pm10 data with date 19910524 is missing
# AQI for pm10 data with date 19910525 is missing
# AQI for pm10 data with date 19910526 is missing
# AQI for pm10 data with date 19910527 is missing
# AQI for pm10 data with date 19910528 is missing
# AQI for pm10 data with date 19910529 is missing
# AQI for pm10 data with date 19910531 is missing
# AQI for pm10 data with date 19910601 is missing
# AQI for pm10 data with date 19910603 is missing
# AQI for pm10 data with date 19910604 is missing
# AQI for pm10 data with date 19910605 is missing
# AQI for pm10 data with date 19910606 is missing
# AQI for pm10 data with date 19910607 is missing
# AQI for pm10 data with date 19910609 is missing
# AQI for pm10 data with date 19910610 is missing
# AQI for pm10 data with date 19910612 is missing
# AQI for pm10 data with date 19910613 is missing
# AQI for pm10 data with date 19910614 is missing
# AQI for pm10 data with date 19910617 is missing
# AQI for pm10 data with date 19910618 is missing
# AQI for pm10 data with date 19910619 is missing
# AQI for pm10 data with date 19910620 is missing
# AQI for pm10 data with date 19910621 is missing
# AQI for pm10 data with date 19910627 is missing
# AQI for pm10 data with date 19910628 is missing
# AQI for pm10 data with date 19910629 is missing
# AQI for pm10 data with date 19910630 is missing
# AQI for pm10 data with date 19910702 is missing
# AQI for pm10 data with date 19910703 is missing
# AQI for pm10 data with date 19910706 is missing
# AQI for pm10 data with date 19910707 is missing
# ...
# AQI for pm10 data with date 20110513 is missing
# AQI for pm10 data with date 20110515 is missing
# AQI for pm10 data with date 20110516 is missing
# AQI for pm10 data with date 20110531 is missing
# AQI for pm10 data with date 20110601 is missing
# AQI for pm10 data with date 20110602 is missing
# AQI for pm10 data with date 20110603 is missing
# AQI for pm10 data with date 20110604 is missing
# AQI for pm10 data with date 20110605 is missing
# AQI for pm10 data with date 20110606 is missing
# AQI for pm10 data with date 20110627 is missing
# AQI for pm10 data with date 20110630 is missing
# AQI for pm10 data with date 20110801 is missing
# AQI for pm10 data with date 20110804 is missing
# AQI for pm10 data with date 20110805 is missing
# AQI for pm10 data with date 20110816 is missing
# AQI for pm10 data with date 20110828 is null
# AQI for pm10 data with date 20111017 is missing
# AQI for pm10 data with date 20111018 is missing
# AQI for pm10 data with date 20111019 is missing
# AQI for pm10 data with date 20111102 is missing
# There were 32 instances of missing data.
# There were 1 null values in the data.
# Total null values retrived: 33
#
# Retrieving pm2.5 Acceptable AQI data
# AQI for pm2.5 acceptable data with date 20110313 is null
# AQI for pm2.5 acceptable data with date 20110314 is null
# There were 2 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 2
# ------------ Retrieving data for 2012 ------------
# Retrieving pm10 AQI data
# AQI for pm10 data with date 20120116 is missing
# AQI for pm10 data with date 20120121 is missing
# AQI for pm10 data with date 20120410 is missing
# AQI for pm10 data with date 20120414 is missing
# AQI for pm10 data with date 20120421 is missing
# AQI for pm10 data with date 20120422 is missing
# AQI for pm10 data with date 20120423 is missing
# AQI for pm10 data with date 20120424 is missing
# AQI for pm10 data with date 20120821 is missing
# AQI for pm10 data with date 20120822 is missing
# AQI for pm10 data with date 20121002 is missing
# AQI for pm10 data with date 20121003 is missing
# AQI for pm10 data with date 20121115 is missing
# There were 13 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 13
#
# Retrieving pm2.5 Acceptable AQI data
# AQI for pm2.5 acceptable data with date 20120821 is null
# AQI for pm2.5 acceptable data with date 20120822 is null
# There were 2 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 2
# ------------ Retrieving data for 2013 ------------
# Retrieving pm10 AQI data
# AQI for pm10 data with date 20130131 is missing
# AQI for pm10 data with date 20130201 is missing
# AQI for pm10 data with date 20130206 is missing
# AQI for pm10 data with date 20130408 is missing
# AQI for pm10 data with date 20130612 is missing
# AQI for pm10 data with date 20130613 is missing
# AQI for pm10 data with date 20130701 is missing
# AQI for pm10 data with date 20130702 is missing
# AQI for pm10 data with date 20130715 is missing
# AQI for pm10 data with date 20130815 is missing
# AQI for pm10 data with date 20130910 is missing
# AQI for pm10 data with date 20130911 is missing
# AQI for pm10 data with date 20130915 is null
# AQI for pm10 data with date 20131028 is null
# AQI for pm10 data with date 20131102 is null
# AQI for pm10 data with date 20131201 is missing
# There were 13 instances of missing data.
# There were 3 null values in the data.
# Total null values retrived: 16
#
# Retrieving pm2.5 Acceptable AQI data
# AQI for pm2.5 acceptable data with date 20130729 is null
# AQI for pm2.5 acceptable data with date 20130822 is null
# There were 2 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 2
# ------------ Retrieving data for 2014 ------------
# Retrieving pm10 AQI data
# AQI for pm10 data with date 20140111 is null
# AQI for pm10 data with date 20140226 is missing
# AQI for pm10 data with date 20140303 is missing
# AQI for pm10 data with date 20140304 is missing
# AQI for pm10 data with date 20140509 is missing
# AQI for pm10 data with date 20140510 is missing
# AQI for pm10 data with date 20140512 is missing
# AQI for pm10 data with date 20140517 is missing
# AQI for pm10 data with date 20140521 is missing
# AQI for pm10 data with date 20140524 is missing
# AQI for pm10 data with date 20140528 is missing
# AQI for pm10 data with date 20140529 is missing
# AQI for pm10 data with date 20140613 is missing
# AQI for pm10 data with date 20140708 is missing
# AQI for pm10 data with date 20140709 is missing
# AQI for pm10 data with date 20140714 is missing
# AQI for pm10 data with date 20140715 is missing
# AQI for pm10 data with date 20140716 is missing
# AQI for pm10 data with date 20140720 is missing
# AQI for pm10 data with date 20140728 is missing
# AQI for pm10 data with date 20140729 is missing
# AQI for pm10 data with date 20140730 is missing
# AQI for pm10 data with date 20140801 is missing
# AQI for pm10 data with date 20140804 is missing
# AQI for pm10 data with date 20140830 is missing
# AQI for pm10 data with date 20141122 is missing
# AQI for pm10 data with date 20141229 is missing
# There were 26 instances of missing data.
# There were 1 null values in the data.
# Total null values retrived: 27
#
# Retrieving pm2.5 Acceptable AQI data
# AQI for pm2.5 acceptable data with date 20140507 is null
# AQI for pm2.5 acceptable data with date 20140509 is null
# AQI for pm2.5 acceptable data with date 20140510 is null
# AQI for pm2.5 acceptable data with date 20140512 is null
# AQI for pm2.5 acceptable data with date 20140517 is null
# AQI for pm2.5 acceptable data with date 20140524 is null
# AQI for pm2.5 acceptable data with date 20140528 is null
# AQI for pm2.5 acceptable data with date 20140529 is null
# AQI for pm2.5 acceptable data with date 20140925 is null
# There were 9 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 9
# ------------ Retrieving data for 2015 ------------
# Retrieving pm10 AQI data
# AQI for pm10 data with date 20150106 is missing
# AQI for pm10 data with date 20150107 is missing
# AQI for pm10 data with date 20150428 is missing
# AQI for pm10 data with date 20150430 is missing
# AQI for pm10 data with date 20150608 is missing
# AQI for pm10 data with date 20150619 is missing
# AQI for pm10 data with date 20150622 is missing
# AQI for pm10 data with date 20150626 is missing
# AQI for pm10 data with date 20150627 is missing
# AQI for pm10 data with date 20150628 is missing
# AQI for pm10 data with date 20150629 is missing
# AQI for pm10 data with date 20150630 is missing
# AQI for pm10 data with date 20150701 is missing
# AQI for pm10 data with date 20150702 is missing
# AQI for pm10 data with date 20150703 is missing
# AQI for pm10 data with date 20150704 is missing
# AQI for pm10 data with date 20150709 is missing
# AQI for pm10 data with date 20150719 is missing
# AQI for pm10 data with date 20150731 is missing
# AQI for pm10 data with date 20150814 is null
# AQI for pm10 data with date 20150828 is missing
# AQI for pm10 data with date 20150908 is missing
# AQI for pm10 data with date 20151030 is null
# AQI for pm10 data with date 20151117 is null
# There were 21 instances of missing data.
# There were 3 null values in the data.
# Total null values retrived: 24
#
# Retrieving pm2.5 Acceptable AQI data
# AQI for pm2.5 acceptable data with date 20150323 is null
# AQI for pm2.5 acceptable data with date 20150330 is null
# AQI for pm2.5 acceptable data with date 20150428 is null
# AQI for pm2.5 acceptable data with date 20150430 is null
# AQI for pm2.5 acceptable data with date 20150619 is null
# AQI for pm2.5 acceptable data with date 20150622 is null
# There were 6 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 6
# ------------ Retrieving data for 2016 ------------
# Retrieving pm10 AQI data
# AQI for pm10 data with date 20160330 is missing
# AQI for pm10 data with date 20160412 is missing
# AQI for pm10 data with date 20160609 is missing
# AQI for pm10 data with date 20160615 is missing
# AQI for pm10 data with date 20161209 is missing
# AQI for pm10 data with date 20161211 is missing
# AQI for pm10 data with date 20161213 is missing
# AQI for pm10 data with date 20161219 is missing
# AQI for pm10 data with date 20161222 is missing
# AQI for pm10 data with date 20161224 is missing
# AQI for pm10 data with date 20161226 is missing
# AQI for pm10 data with date 20161229 is missing
# There were 12 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 12
#
# Retrieving pm2.5 Acceptable AQI data
# AQI for pm2.5 acceptable data with date 20160905 is null
# AQI for pm2.5 acceptable data with date 20161018 is null
# There were 2 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 2
# ------------ Retrieving data for 2017 ------------
# Retrieving pm10 AQI data
# AQI for pm10 data with date 20170905 is null
# AQI for pm10 data with date 20170906 is null
# There were 0 instances of missing data.
# There were 2 null values in the data.
# Total null values retrived: 2
#
# Retrieving pm2.5 Acceptable AQI data
# There were 0 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 0
# ------------ Retrieving data for 2018 ------------
# Retrieving pm10 AQI data
# There were 0 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 0
#
# Retrieving pm2.5 Acceptable AQI data
# There were 0 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 0
# ------------ Retrieving data for 2019 ------------
# Retrieving pm10 AQI data
# AQI for pm10 data with date 20190401 is missing
# AQI for pm10 data with date 20190722 is missing
# AQI for pm10 data with date 20190724 is missing
# AQI for pm10 data with date 20190730 is missing
# AQI for pm10 data with date 20190820 is missing
# AQI for pm10 data with date 20191007 is missing
# AQI for pm10 data with date 20190128 is missing
# There were 7 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 7
#
# Retrieving pm2.5 Acceptable AQI data
# AQI for pm2.5 acceptable data with date 20191007 is null
# There were 1 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 1
# ------------ Retrieving data for 2020 ------------
# Retrieving pm10 AQI data
# AQI for pm10 data with date 20200415 is missing
# AQI for pm10 data with date 20200821 is missing
# AQI for pm10 data with date 20200825 is missing
# There were 3 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 3
#
# Retrieving pm2.5 Acceptable AQI data
# AQI for pm2.5 acceptable data with date 20200415 is null
# There were 1 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 1
# ------------ Retrieving data for 2021 ------------
# Retrieving pm10 AQI data
# AQI for pm10 data with date 20210617 is missing
# AQI for pm10 data with date 20210621 is missing
# There were 2 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 2
#
# Retrieving pm2.5 Acceptable AQI data
# AQI for pm2.5 acceptable data with date 20210401 is null
# AQI for pm2.5 acceptable data with date 20210402 is null
# AQI for pm2.5 acceptable data with date 20210403 is null
# AQI for pm2.5 acceptable data with date 20210404 is null
# AQI for pm2.5 acceptable data with date 20210405 is null
# AQI for pm2.5 acceptable data with date 20210406 is null
# AQI for pm2.5 acceptable data with date 20210407 is null
# AQI for pm2.5 acceptable data with date 20210408 is null
# AQI for pm2.5 acceptable data with date 20210409 is null
# AQI for pm2.5 acceptable data with date 20210410 is null
# AQI for pm2.5 acceptable data with date 20210411 is null
# AQI for pm2.5 acceptable data with date 20210412 is null
# AQI for pm2.5 acceptable data with date 20210430 is null
# AQI for pm2.5 acceptable data with date 20210506 is null
# AQI for pm2.5 acceptable data with date 20210507 is null
# AQI for pm2.5 acceptable data with date 20210508 is null
# AQI for pm2.5 acceptable data with date 20210509 is null
# AQI for pm2.5 acceptable data with date 20210510 is null
# AQI for pm2.5 acceptable data with date 20210511 is null
# AQI for pm2.5 acceptable data with date 20210512 is null
# AQI for pm2.5 acceptable data with date 20210513 is null
# AQI for pm2.5 acceptable data with date 20210514 is null
# AQI for pm2.5 acceptable data with date 20210515 is null
# AQI for pm2.5 acceptable data with date 20210516 is null
# AQI for pm2.5 acceptable data with date 20210517 is null
# AQI for pm2.5 acceptable data with date 20210518 is null
# AQI for pm2.5 acceptable data with date 20210519 is null
# AQI for pm2.5 acceptable data with date 20210520 is null
# AQI for pm2.5 acceptable data with date 20210521 is null
# AQI for pm2.5 acceptable data with date 20210522 is null
# AQI for pm2.5 acceptable data with date 20210523 is null
# AQI for pm2.5 acceptable data with date 20210524 is null
# AQI for pm2.5 acceptable data with date 20210525 is null
# AQI for pm2.5 acceptable data with date 20210526 is null
# AQI for pm2.5 acceptable data with date 20210527 is null
# AQI for pm2.5 acceptable data with date 20210528 is null
# AQI for pm2.5 acceptable data with date 20210529 is null
# AQI for pm2.5 acceptable data with date 20210530 is null
# AQI for pm2.5 acceptable data with date 20210531 is null
# AQI for pm2.5 acceptable data with date 20210601 is null
# AQI for pm2.5 acceptable data with date 20210602 is null
# AQI for pm2.5 acceptable data with date 20210603 is null
# AQI for pm2.5 acceptable data with date 20210604 is null
# AQI for pm2.5 acceptable data with date 20210605 is null
# AQI for pm2.5 acceptable data with date 20210606 is null
# AQI for pm2.5 acceptable data with date 20210607 is null
# AQI for pm2.5 acceptable data with date 20210608 is null
# AQI for pm2.5 acceptable data with date 20210609 is null
# AQI for pm2.5 acceptable data with date 20210610 is null
# AQI for pm2.5 acceptable data with date 20210611 is null
# AQI for pm2.5 acceptable data with date 20210612 is null
# AQI for pm2.5 acceptable data with date 20210613 is null
# AQI for pm2.5 acceptable data with date 20210614 is null
# AQI for pm2.5 acceptable data with date 20210615 is null
# AQI for pm2.5 acceptable data with date 20210616 is null
# AQI for pm2.5 acceptable data with date 20210617 is null
# AQI for pm2.5 acceptable data with date 20210618 is null
# AQI for pm2.5 acceptable data with date 20210619 is null
# AQI for pm2.5 acceptable data with date 20210620 is null
# AQI for pm2.5 acceptable data with date 20210621 is null
# AQI for pm2.5 acceptable data with date 20210622 is null
# AQI for pm2.5 acceptable data with date 20210623 is null
# AQI for pm2.5 acceptable data with date 20210624 is null
# AQI for pm2.5 acceptable data with date 20210625 is null
# AQI for pm2.5 acceptable data with date 20210626 is null
# AQI for pm2.5 acceptable data with date 20210627 is null
# AQI for pm2.5 acceptable data with date 20210628 is null
# AQI for pm2.5 acceptable data with date 20210629 is null
# AQI for pm2.5 acceptable data with date 20210630 is null
# There were 0 instances of missing data.
# There were 69 null values in the data.
# Total null values retrived: 69
# ------------ Retrieving data for 2022 ------------
# Retrieving pm10 AQI data
# AQI for pm10 data with date 20221013 is missing
# AQI for pm10 data with date 20221017 is missing
# There were 2 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 2
#
# Retrieving pm2.5 Acceptable AQI data
# AQI for pm2.5 acceptable data with date 20220420 is null
# There were 1 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived: 1
# ------------ Retrieving data for 2023 ------------
# Retrieving pm10 AQI data
# AQI for pm10 data with date 20230313 is missing
# AQI for pm10 data with date 20230314 is missing
# AQI for pm10 data with date 20230614 is missing
# AQI for pm10 data with date 20230621 is missing
# There were 4 instances of missing data.
# There were 0 null values in the data.
# Total null values retrived:
# Now, my classmate, Emily Rolen, recommended I select the larger AQI value of pm10 and pm2.5 for my overall AQI value for each day, and I like this idea. Based upon my exploratory work earlier into the 0002 Site sensor, we know that the pm10 detector has an open date of 2019-04-01, while the pm2.5 acceptable has an open date of 2005-10-19. Based upon this info, let's find the max AQI and store it.

# %% [markdown]
# **TBD Decision, right now, the next cell allows AQI to be None if necessary. should I change to a constant like '-1'?**
# **Also, issue of missing keys from pm10!!!??????????????**

# %% [markdown]
# **TBD: rewrite the code below. Instead iterate through every day in the range. Check if the key exists in both dictionaries and compare values. This will handle coverage issue.**

# %%
pm10_aqi_keys = pm10_aqi_dict.keys()
pm25_aqi_keys = pm25_aqi_dict.keys()

aqi_dict = {}
pm25_key_index = 0
# iterate through the pm2.5 data. we can assume the pm2.5 aqi dataframe has more values since it's monitor has been open longer
for key in tqdm(pm25_aqi_keys):
    pm25_aqi = pm25_aqi_dict[key]
    
    #check if we have reached first possible date for both dataframes to have values
    try:
        # check if the pm10 dictionary has an entry for the current date/key
        pm10_aqi = pm10_aqi_dict[key]
    
    except: #if key doesn't exist use the value from pm25
        max_aqi = pm25_aqi
    
    else: #if pm10 does have an entry for that key choose the max
        
        # handle null values
        if (pm10_aqi is None) and (pm25_aqi is None):
            max_aqi = None
            
        elif pm10_aqi is None:
            max_aqi = pm25_aqi
            
        elif pm25_aqi is None:
            max_aqi = pm10_aqi
            
        else: # if neither are null compare them and pick largest
            if pm10_aqi >= pm25_aqi:
                max_aqi = pm10_aqi
            else:
                max_aqi = pm25_aqi 
        
    #save the value
    aqi_dict[key] = max_aqi

# %%
# aqi_dict

# %% [markdown]
# **TBD: understand why comment doesn't work**

# %% [markdown]
# Now we convert the AQI dictionary to a pandas data frame

# %%
# I referenced: https://www.geeksforgeeks.org/how-to-create-dataframe-from-dictionary-in-python-pandas/#
# and: https://stackoverflow.com/questions/17839973/constructing-pandas-dataframe-from-values-in-variables-gives-valueerror-if-usi
# and: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html
# and: https://sparkbyexamples.com/pandas/pandas-create-new-dataframe-by-selecting-specific-columns/#:~:text=You%20can%20create%20a%20new,added%20to%20the%20original%20ones.
# df_aqi = pd.DataFrame.from_records(aqi_dict)
# helpful to understand erorr in line above: df_aqi = pd.DataFrame().assign(aqi_dict)

df_daily_aqi = pd.DataFrame({
    'Date' : aqi_dict.keys(),
    'AQI' : aqi_dict.values()
})
df_daily_aqi

# %% [markdown]
# **TBD:**

# %% [markdown]
# Potential Issues/Big Assumptions:
# - This method will ensure that every date in the pm2.5 data will be included, but no check for whether every date in pm10 will be.

# %% [markdown]
# Next, we find the annual AQI. First we have to add a column to the daily aqi data frame representing each year

# %%
# Sources I referenced to review how to format dates:
# https://docs.python.org/3/library/datetime.html#format-codes
# https://stackoverflow.com/questions/55542280/why-does-python-3-find-this-iso8601-date-2019-04-05t165526z-invalid
# https://stackoverflow.com/questions/19934248/nameerror-name-datetime-is-not-defined

my_date = datetime.strptime('20210701', '%Y%m%d')
my_date.year

year_list = []
# iterate through the dataframe
for index, row in df_daily_aqi.iterrows():
    date = row['Date']
    my_date = datetime.strptime(date, '%Y%m%d')
    year_list.append(my_date.year)
    
# add the years to the dataframe
df_daily_aqi['Year'] = year_list
df_daily_aqi = df_daily_aqi[['Year', 'Date', 'AQI']]
df_daily_aqi

# %% [markdown]
# Note, that there may be days when the sensor did not record data for either pollutant type. For example, I tested the code on acquiring data from 2021 and the dataframe with daily AQI values had data for 343 rows, not 365. While this is not ideal, we proceed using this method as it still provides some helpful data.

# %% [markdown]
# **LO: If have time add a column daily aqi dataframe for tracking what proportion of days each year had data.**

# %% [markdown]
# Now that we have the daily aqi, let's find the average aqi for the recorded days for each year and save the result.

# %%
# I viewed: https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.DataFrameGroupBy.aggregate.html
# to remind myself how to do a groupby
df_annual_avg_aqi = df_daily_aqi.groupby('Year').agg('mean')
df_annual_avg_aqi

# %%
df_annual_avg_aqi.to_csv('Annual_AQI_Average.csv')

# %% [markdown]
# Steps:
# - create a dataframe
# - add a column for smoke estimate calculation
#
# For the step 2 visualizations, the data should be in a dataframe form. That way I can group by year

# %% [markdown]
# ## References:
# - Learning to use .gitignore:
#     * https://stackoverflow.com/questions/19663093/apply-gitignore-on-an-existing-repository-already-tracking-large-number-of-file
#     * https://stackoverflow.com/questions/40441450/relative-parent-directory-path-for-gitignore
# - Learning to work with GIS data:
#     * [3] wildfire_geo_proximity_example.ipynb. //"This code example was developed by Dr. David W. McDonald for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [Creative Commons](https://creativecommons.org) [CC-BY license](https://creativecommons.org/licenses/by/4.0/). Revision 1.0 - August 13, 2023"
# - [4]. Proffessor's wildfire module
# - [5]. https://www.latlong.net/place/west-richland-wa-usa-25340.html
# - [6]. https://stackoverflow.com/questions/12268930/create-json-with-multiple-dictionaries-python
# - [7]. https://www.geeksforgeeks.org/reading-and-writing-json-to-a-file-in-python/#
# - [8]. https://www.w3schools.com/python/python_try_except.asp
# - [9]. 'DATA 512 Homework 1 Acquire Process and Analyze Data.ipynb' at: https://github.com/logan-obrien/data-512-homework_1.git
# - [10]. https://www.airnow.gov/aqi/aqi-basics/
# - [11]. https://www.google.com/search?q=how+to+convert+acres+to+square+miles&rlz=1C1RXQR_enUS1019US1019&oq=how+to+convert+from+acres+to+s&gs_lcrp=EgZjaHJvbWUqCAgDEAAYFhgeMgYIABBFGDkyCAgBEAAYFhgeMggIAhAAGBYYHjIICAMQABgWGB4yCAgEEAAYFhgeMgoIBRAAGIYDGIoFMgoIBhAAGIYDGIoF0gEIOTU3MmowajeoAgCwAgA&sourceid=chrome&ie=UTF-8
# - [12]. https://www.geeksforgeeks.org/numpy-argmax-python/
# - [13]. https://numpy.org/doc/stable/reference/generated/numpy.argmax.html
# - [14]. epa_air_quality_history_example.ipynb //"This code example was developed by Dr. David W. McDonald for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [Creative Commons](https://creativecommons.org) [CC-BY license](https://creativecommons.org/licenses/by/4.0/). Revision 1.1 - September 5, 2023"
# - [15]. https://www.census.gov/library/reference/code-lists/ansi.html#cousub
# - [16]. https://www2.census.gov/geo/docs/reference/codes2020/cousub/st53_wa_cousub2020.txt
# - [17]. https://www.airnow.gov/sites/default/files/2020-05/aqi-technical-assistance-document-sept2018.pdf
# - [18]. https://www.epa.gov/wildfire-smoke-course/why-wildfire-smoke-health-concern
